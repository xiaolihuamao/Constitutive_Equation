# %% [markdown]
# ## LSTM应力应变曲线

# %%
from time import time
from datetime import datetime
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import random, genfromtxt
from IPython.display import display
from matplotlib import rc
from matplotlib.pyplot import figure
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn.functional as F
import matplotlib.ticker as mticker
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from torch.utils.data import DataLoader, TensorDataset

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# /home/redfu/work/Constitutive_Equation/stress_strain_fitting

# %%
# 设置数据类型
DTYPE = torch.float32

# 设置随机种子
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)

df = {}
# 读取数据
url = 'data/sin_maxwell_data.xlsx'

df = pd.read_excel(url, sheet_name=None)
data_HF = [[k, v] for k, v in df.items()]  # k is the sheet name, v is the pandas df
# 循环遍历 data_HF 列表并获取下标
data_train=pd.DataFrame()
data_valid=pd.DataFrame()
for i, (sheet_name, sheet_data) in enumerate(data_HF):
    # 去除 sheet_data 中的零值
    sheet_data = sheet_data[(sheet_data != 0).all(axis=1)]
    if i==2:
        data_valid=sheet_data
    else:
        data_train=pd.concat([data_train, sheet_data], ignore_index=True)

df_hf = pd.concat([data_train, data_valid], ignore_index=True)


x1_d_HF = torch.tensor(data_train['Strain'].values, dtype=torch.float32).view(-1, 1)
x2_d_HF = torch.tensor(data_train['n'].values, dtype=torch.float32).view(-1, 1)
x3_d_HF = torch.tensor(data_train['Time'].values, dtype=torch.float32).view(-1, 1)
y1_d_HF = torch.tensor(data_train['Stress'].values, dtype=torch.float32).view(-1, 1)
# 计算边界

x1min, x1max = torch.min(x1_d_HF), torch.max(x1_d_HF)
x2min, x2max = torch.min(x2_d_HF), torch.max(x2_d_HF)
x3min, x3max = torch.min(x3_d_HF), torch.max(x3_d_HF)
y1min, y1max = torch.min(y1_d_HF), torch.max(y1_d_HF)

lb = torch.tensor([x1min, x2min,x3min, y1min], dtype=torch.float32).numpy()
ub = torch.tensor([x1max, x2max,x3max,y1max], dtype=torch.float32).numpy()
# 归一化函数
def norm(vectors, lb, ub):
    normalized_vectors = (vectors - lb) / (ub - lb)
    return normalized_vectors

x1_d_HF = norm(x1_d_HF, lb[0], ub[0])
x2_d_HF = norm(x2_d_HF, lb[1], ub[1])
x3_d_HF = norm(x3_d_HF, lb[2], ub[2])
y1_d_HF = norm(y1_d_HF, lb[3], ub[3])
# 合并数据
X_data_HF = torch.cat([x1_d_HF, x2_d_HF,x3_d_HF], dim=1)
y_data_HF= torch.cat([y1_d_HF], dim=1) # 默认训练储存模量




# 定义模型
in_dim, out_dim = 3, 1

# %% [markdown]
# ### 通过滑动窗口构建序列数据

# %%
# 定义时间步长
time_steps = 2

# 动态窗口实现
def create_dynamic_window(data, time_steps):
    """
    通过动态窗口将数据调整为适合 LSTM 输入的格式。
    :param data: 输入数据，形状为 (num_samples, ...)
    :param time_steps: 时间步长
    :return: 调整后的数据，形状为 (num_samples - time_steps + 1, time_steps, ...)
    """
    num_samples = data.shape[0]
    if num_samples < time_steps:
        raise ValueError("样本数量必须大于等于时间步长")
    
    # 创建动态窗口
    windowed_data = []
    for i in range(num_samples - time_steps + 1):
        window = data[i:i + time_steps]
        windowed_data.append(window)
    
    return torch.stack(windowed_data)

# 调整 X_data_HF
X_data_HF = create_dynamic_window(X_data_HF, time_steps)

# 调整 y_data_HF
# 注意：y_data_HF 通常是目标值，只需要取最后一个时间步的值
y_data_HF = y_data_HF[time_steps - 1:]

# %%
x1_d_valid = torch.tensor(data_valid['Strain'].values, dtype=torch.float32).view(-1, 1)
x2_d_valid = torch.tensor(data_valid['n'].values, dtype=torch.float32).view(-1, 1)
x3_d_valid = torch.tensor(data_valid['Time'].values, dtype=torch.float32).view(-1, 1)

y1_d_valid = torch.tensor(data_valid['Stress'].values, dtype=torch.float32).view(-1, 1)

x1_d_valid = norm(x1_d_valid, lb[0], ub[0])
x2_d_valid = norm(x2_d_valid, lb[1], ub[1])
x3_d_valid = norm(x3_d_valid, lb[2], ub[2])
y1_d_valid = norm(y1_d_valid, lb[3], ub[3])

# 合并数据
X_data_valid = torch.cat([x1_d_valid, x2_d_valid,x3_d_valid], dim=1)
y_data_valid= torch.cat([y1_d_valid], dim=1)

# %%
# 调整 X_data_valid
X_data_valid = create_dynamic_window(X_data_valid, time_steps)
# 调整 y_data_HF
# 注意：y_data_HF 通常是目标值，只需要取最后一个时间步的值
y_data_valid = y_data_valid[time_steps - 1:]

# %%
# 神经网络的类
class PINN_NeuralNet(nn.Module):
    """ Set basic architecture of the PINN model using LSTM."""

    def __init__(self,
                 input_dim=0,
                 output_dim=1,  # 默认输出维度为1
                 hidden_size=20,  # LSTM 隐藏层的维度
                 num_layers=4,    # LSTM 层数
                 activation='tanh',
                 kernel_initializer='glorot_normal',
                 **kwargs):
        super(PINN_NeuralNet, self).__init__()

        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_dim = output_dim

        # 添加 LSTM 层
        self.lstm = nn.LSTM(input_dim, hidden_size, num_layers, batch_first=True)
        
        # 添加输出层
        self.out = nn.Linear(hidden_size, output_dim)
        
        # 设置激活函数
        if activation == 'tanh':
            self.activation = torch.tanh
        elif activation == 'relu':
            self.activation = F.relu6
        elif activation == 'sigmoid':
            self.activation = torch.sigmoid
        elif activation == 'linear':
            self.activation = None
        else:
            raise ValueError("Unsupported activation function")
        
        # 初始化权重
        if kernel_initializer == 'glorot_normal':
            for name, param in self.lstm.named_parameters():
                if 'weight' in name:
                    nn.init.xavier_normal_(param)
            nn.init.xavier_normal_(self.out.weight)
        elif kernel_initializer == 'glorot_uniform':
            for name, param in self.lstm.named_parameters():
                if 'weight' in name:
                    nn.init.xavier_uniform_(param)
            nn.init.xavier_uniform_(self.out.weight)
        else:
            raise ValueError("Unsupported kernel initializer")

    def forward(self, X):
        # LSTM 输入形状: (batch_size, seq_len, input_dim)
        # LSTM 输出形状: (batch_size, seq_len, hidden_size)
        # 初始化隐藏状态和细胞状态
        h0 = torch.zeros(self.num_layers, X.size(0), self.hidden_size).to(X.device)
        c0 = torch.zeros(self.num_layers, X.size(0), self.hidden_size).to(X.device)
        
        # 通过 LSTM 层
        lstm_out, _ = self.lstm(X, (h0, c0))
        
        # 取最后一个时间步的输出
        last_time_step = lstm_out[:, -1, :]  # (batch_size, hidden_size)
        
        # 通过输出层
        Z = self.out(last_time_step)
        
        # 应用激活函数（如果需要）
        if self.activation is not None:
            Z = self.activation(Z)
        
        return Z

# %%
# 神经网络处理器类
class PINNSolver():

    # 类属性定义
    def __init__(self, model):
        self.model = model # 
        # Initialize history of losses and global iteration counter
        self.hist =  [[], []] # loss历史列表,0:train loss ;1:valid loss
        self.iter = 0 # 迭代次数
        self.last_n_losses = [] # 前损失列表

    # 更新损失列表   
    def update_last_n_losses(self, loss):
        self.last_n_losses.append(loss)
        if len(self.last_n_losses) > 20:
            self.last_n_losses.pop(0)

    # 计算最大相对误差        
    def ES(self):
        if len(self.last_n_losses) < 20:
            return 100  # a large number

        current_loss = self.last_n_losses[-1]
        max_relative_error = 100.*max([abs(current_loss - loss) / current_loss for loss in self.last_n_losses[:-1]])
        return max_relative_error
    
    # 计算loss，模型核心
    def loss_fn(self, X_data_HF, y_data_HF,X_data_valid,y_data_valid):
        y_pred_valid = self.model(X_data_valid)    
    
        y_pred_HF = self.model(X_data_HF)

        Loss_L2 = 1e-5 * sum(torch.sum(w_**2) for w_ in self.model.parameters())
        Loss_data_HF = torch.mean((y_data_HF - y_pred_HF)**2)+Loss_L2
        Loss_data_valid=torch.mean((y_pred_valid-y_data_valid)**2)+Loss_L2
        return Loss_data_HF,Loss_data_valid
    
    # 训练核心函数，包括loss计算梯度计算和反向传播
    def solve_with_PyTorch_optimizer(self, optimizer, data, scheduler, batch_size, N=1001):
        """This method performs a gradient descent type optimization."""
        # 解包数据
        X_data_HF, y_data_HF, X_data_valid, y_data_valid = data

        # 创建训练数据集和 DataLoader
        train_dataset = TensorDataset(X_data_HF, y_data_HF)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
        for i in range(N):
            # 初始化 epoch 的总损失
            epoch_loss_sum = 0.0
            num_batches = 0
            # 遍历每个批次
            for X_batch, y_batch in train_loader:
                # 梯度清0
                optimizer.zero_grad()
                # 计算 loss
                loss, _ = self.loss_fn(X_batch, y_batch, X_data_valid, y_data_valid)

                # 反向传播计算梯度
                loss.backward()

                # 反向传播更新权重和偏置
                optimizer.step()

                # 累加每个批次的损失
                epoch_loss_sum += loss.item()
                num_batches += 1

            # 计算 epoch 的平均损失
            # 在整个验证集上计算验证损失
            loss_train, loss_valid = self.loss_fn(X_data_HF, y_data_HF, X_data_valid, y_data_valid)

            # 记录 epoch 的平均损失
            self.current_loss = loss_train.item()
            self.valid_loss = loss_valid.item()
            # 根据 epoch 的平均损失调度学习率
            scheduler.step(loss_train)
            
            # 计算相对误差
            self.max_relative_error = self.ES()
            self.callback(self.max_relative_error, N)  # 将 max_relative_error 传递给回调函数
            self.update_last_n_losses(self.current_loss)

            # 早停机制
            if self.max_relative_error < 2e-3:  # 以 % 为单位
                print('Early stopping... \nIt {:05,d}: Loss = {:10.4e}, Max. rel. error = {} %'.format(self.iter,
                                                                                                    self.current_loss,
                                                                                                    np.round(self.max_relative_error, 3)))
                break
    # 打印loss    
    def callback(self, xr=None,N=1001):
        if self.iter % 10 == 0:
            print('It {:05,d}: Loss = {:10.4e}, Max. rel. error = {} %'.format(self.iter,
                                                             self.current_loss,
                                                            np.round(self.max_relative_error, 2)))
        self.hist[0].append(self.current_loss)
        self.hist[1].append(self.valid_loss)
        self.iter+=1
    
    def plot_loss_history(self, ax=None):
        if not ax:
            fig = plt.figure(figsize=(7, 5))
            ax = fig.add_subplot(111)

        # 绘制训练集损失曲线
        ax.semilogy(range(len(self.hist[0])), self.hist[0], 'b-', label='Training Loss')
        
        # 绘制验证集损失曲线
        ax.semilogy(range(len(self.hist[1])), self.hist[1], 'g-', label='Validation Loss')

        ax.set_xlabel('$n_{epoch}$')
        ax.set_ylabel('$loss$')
        ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, pos: f'{int(x):,}'))
        ax.legend()  # 添加图例
        return ax

# %%
model= PINN_NeuralNet(input_dim=in_dim,
                             output_dim=out_dim,
                             num_layers=4,
                             hidden_size=10,
                             activation='relu')

# 初始化 PINNSolver
solver = PINNSolver(model)

# %%
# 定义学习率调度器
lr = 1e-2
optimizer = optim.Adam(list(model.parameters()), lr=lr)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.9, patience=10, verbose=True)
batch=1000
# 定义训练模式
mode = 'PyTorch_optimizer'
N = int(3000) + 1  # 训练迭代次数

try:
    runtime
except NameError:
    runtime = 0.

if mode == 'PyTorch_optimizer':
    try:
        t0 = time()
        solver.solve_with_PyTorch_optimizer(optimizer, [X_data_HF,y_data_HF,X_data_valid,y_data_valid],scheduler,batch,N=N)
        runtime += (time() - t0) / 60.
        print('\nRuntime: {:.3f} minutes'.format(runtime))
    except KeyboardInterrupt:
        runtime += (time() - t0) / 60.
        print('\nRuntime: {:.3f} minutes'.format(runtime))
# Out:
# It 0,000: Loss = 1.1520e-01, Max. rel. error = 100 %
# It 0,010: Loss = 1.0824e-01, Max. rel. error = 100 %
# It 0,020: Loss = 1.0595e-01, Max. rel. error = 13.16 %
# It 0,030: Loss = 9.8854e-02, Max. rel. error = 9.29 %
# It 0,040: Loss = 9.7300e-02, Max. rel. error = 8.73 %
# It 0,050: Loss = 9.6459e-02, Max. rel. error = 2.44 %
# It 0,060: Loss = 9.6095e-02, Max. rel. error = 1.26 %
# It 0,070: Loss = 9.6333e-02, Max. rel. error = 1.62 %
# It 0,080: Loss = 9.6714e-02, Max. rel. error = 10.95 %
# Epoch    89: reducing learning rate of group 0 to 9.0000e-03.
# It 0,090: Loss = 9.2074e-02, Max. rel. error = 18.5 %
# It 0,100: Loss = 1.0334e-01, Max. rel. error = 27.49 %
# Epoch   108: reducing learning rate of group 0 to 8.1000e-03.
# It 0,110: Loss = 9.0453e-02, Max. rel. error = 30.73 %
# It 0,120: Loss = 7.5628e-02, Max. rel. error = 31.84 %
# It 0,130: Loss = 9.7792e-02, Max. rel. error = 22.85 %
# Epoch   132: reducing learning rate of group 0 to 7.2900e-03.
# It 0,140: Loss = 9.4268e-02, Max. rel. error = 20.05 %
# Epoch   143: reducing learning rate of group 0 to 6.5610e-03.
# It 0,150: Loss = 9.0519e-02, Max. rel. error = 7.52 %
# Epoch   154: reducing learning rate of group 0 to 5.9049e-03.
# It 0,160: Loss = 8.6121e-02, Max. rel. error = 8.85 %
# Epoch   165: reducing learning rate of group 0 to 5.3144e-03.
# It 0,170: Loss = 7.8048e-02, Max. rel. error = 14.02 %
# It 0,180: Loss = 7.2528e-02, Max. rel. error = 78.68 %
# It 0,190: Loss = 6.6007e-02, Max. rel. error = 197.53 %
# Epoch   193: reducing learning rate of group 0 to 4.7830e-03.
# It 0,200: Loss = 3.4600e-02, Max. rel. error = 391.02 %
# It 0,210: Loss = 6.3285e-02, Max. rel. error = 76.31 %
# Epoch   219: reducing learning rate of group 0 to 4.3047e-03.
# It 0,220: Loss = 3.8485e-02, Max. rel. error = 657.11 %
# It 0,230: Loss = 1.8008e-02, Max. rel. error = 1381.31 %
# It 0,240: Loss = 1.1630e-02, Max. rel. error = 223.52 %
# It 0,250: Loss = 9.5237e-03, Max. rel. error = 86.91 %
# It 0,260: Loss = 1.0304e-02, Max. rel. error = 19.03 %
# Epoch   270: reducing learning rate of group 0 to 3.8742e-03.
# It 0,270: Loss = 1.0743e-02, Max. rel. error = 96.7 %
# It 0,280: Loss = 7.9301e-03, Max. rel. error = 246.65 %
# It 0,290: Loss = 7.5330e-03, Max. rel. error = 42.1 %
# It 0,300: Loss = 7.2866e-03, Max. rel. error = 8.8 %
# It 0,310: Loss = 9.4153e-03, Max. rel. error = 6.52 %
# Epoch   314: reducing learning rate of group 0 to 3.4868e-03.
# It 0,320: Loss = 8.6354e-03, Max. rel. error = 68.35 %
# It 0,330: Loss = 6.8667e-03, Max. rel. error = 107.81 %
# It 0,340: Loss = 6.7319e-03, Max. rel. error = 27.87 %
# It 0,350: Loss = 6.6411e-03, Max. rel. error = 4.17 %
# It 0,360: Loss = 7.2219e-03, Max. rel. error = 11.46 %
# Epoch   366: reducing learning rate of group 0 to 3.1381e-03.
# It 0,370: Loss = 7.3522e-03, Max. rel. error = 49.99 %
# It 0,380: Loss = 6.4184e-03, Max. rel. error = 57.13 %
# It 0,390: Loss = 6.3248e-03, Max. rel. error = 16.09 %
# It 0,400: Loss = 6.2560e-03, Max. rel. error = 2.56 %
# It 0,410: Loss = 6.1945e-03, Max. rel. error = 2.05 %
# It 0,420: Loss = 6.1748e-03, Max. rel. error = 3.89 %
# Epoch   430: reducing learning rate of group 0 to 2.8243e-03.
# It 0,430: Loss = 6.6648e-03, Max. rel. error = 27.55 %
# It 0,440: Loss = 6.0729e-03, Max. rel. error = 47.88 %
# It 0,450: Loss = 5.9854e-03, Max. rel. error = 22.52 %
# It 0,460: Loss = 5.9271e-03, Max. rel. error = 2.6 %
# It 0,470: Loss = 5.8915e-03, Max. rel. error = 1.56 %
# It 0,480: Loss = 5.9430e-03, Max. rel. error = 2.93 %
# Epoch   490: reducing learning rate of group 0 to 2.5419e-03.
# It 0,490: Loss = 7.0951e-03, Max. rel. error = 27.32 %
# It 0,500: Loss = 5.7859e-03, Max. rel. error = 37.54 %
# It 0,510: Loss = 5.7433e-03, Max. rel. error = 24.04 %
# It 0,520: Loss = 5.6667e-03, Max. rel. error = 2.86 %
# It 0,530: Loss = 5.6263e-03, Max. rel. error = 2.17 %
# It 0,540: Loss = 5.5909e-03, Max. rel. error = 1.76 %
# It 0,550: Loss = 6.7196e-03, Max. rel. error = 20.88 %
# Epoch   552: reducing learning rate of group 0 to 2.2877e-03.
# It 0,560: Loss = 5.5321e-03, Max. rel. error = 34.67 %
# It 0,570: Loss = 5.4787e-03, Max. rel. error = 43.44 %
# It 0,580: Loss = 5.4490e-03, Max. rel. error = 6.38 %
# It 0,590: Loss = 5.4078e-03, Max. rel. error = 1.45 %
# It 0,600: Loss = 5.3678e-03, Max. rel. error = 0.74 %
# It 0,610: Loss = 5.7712e-03, Max. rel. error = 1.2 %
# Epoch   612: reducing learning rate of group 0 to 2.0589e-03.
# It 0,620: Loss = 5.3396e-03, Max. rel. error = 8.72 %
# It 0,630: Loss = 5.2758e-03, Max. rel. error = 9.24 %
# It 0,640: Loss = 5.2664e-03, Max. rel. error = 1.65 %
# It 0,650: Loss = 5.2287e-03, Max. rel. error = 0.56 %
# It 0,660: Loss = 5.6343e-03, Max. rel. error = 6.95 %
# Epoch   671: reducing learning rate of group 0 to 1.8530e-03.
# It 0,670: Loss = 7.0184e-03, Max. rel. error = 26.58 %
# It 0,680: Loss = 5.2689e-03, Max. rel. error = 37.33 %
# It 0,690: Loss = 5.1011e-03, Max. rel. error = 37.37 %
# It 0,700: Loss = 5.0776e-03, Max. rel. error = 3.73 %
# It 0,710: Loss = 5.0523e-03, Max. rel. error = 1.01 %
# It 0,720: Loss = 5.0215e-03, Max. rel. error = 1.09 %
# It 0,730: Loss = 4.9933e-03, Max. rel. error = 1.14 %
# It 0,740: Loss = 4.9693e-03, Max. rel. error = 0.88 %
# It 0,750: Loss = 5.0770e-03, Max. rel. error = 1.19 %
# Epoch   756: reducing learning rate of group 0 to 1.6677e-03.
# It 0,760: Loss = 5.0433e-03, Max. rel. error = 9.62 %
# It 0,770: Loss = 4.8905e-03, Max. rel. error = 15.28 %
# It 0,780: Loss = 4.8637e-03, Max. rel. error = 6.21 %
# It 0,790: Loss = 4.8372e-03, Max. rel. error = 1.01 %
# It 0,800: Loss = 4.8133e-03, Max. rel. error = 0.82 %
# It 0,810: Loss = 4.8406e-03, Max. rel. error = 0.48 %
# Epoch   819: reducing learning rate of group 0 to 1.5009e-03.
# It 0,820: Loss = 5.3808e-03, Max. rel. error = 11.94 %
# It 0,830: Loss = 4.7401e-03, Max. rel. error = 20.39 %
# It 0,840: Loss = 4.7102e-03, Max. rel. error = 14.08 %
# It 0,850: Loss = 4.6917e-03, Max. rel. error = 1.3 %
# It 0,860: Loss = 4.6669e-03, Max. rel. error = 1.0 %
# It 0,870: Loss = 4.6717e-03, Max. rel. error = 1.22 %
# Epoch   881: reducing learning rate of group 0 to 1.3509e-03.
# It 0,880: Loss = 5.4199e-03, Max. rel. error = 17.72 %
# It 0,890: Loss = 4.7031e-03, Max. rel. error = 22.16 %
# It 0,900: Loss = 4.5777e-03, Max. rel. error = 18.25 %
# It 0,910: Loss = 4.5569e-03, Max. rel. error = 3.2 %
# It 0,920: Loss = 4.5384e-03, Max. rel. error = 0.88 %
# It 0,930: Loss = 4.5183e-03, Max. rel. error = 0.83 %
# It 0,940: Loss = 4.4951e-03, Max. rel. error = 0.87 %
# It 0,950: Loss = 4.5660e-03, Max. rel. error = 0.83 %
# It 0,960: Loss = 5.3122e-03, Max. rel. error = 11.42 %
# Epoch   963: reducing learning rate of group 0 to 1.2158e-03.
# It 0,970: Loss = 4.7357e-03, Max. rel. error = 41.73 %
# It 0,980: Loss = 4.4236e-03, Max. rel. error = 49.92 %
# It 0,990: Loss = 4.3967e-03, Max. rel. error = 7.67 %
# It 1,000: Loss = 4.3804e-03, Max. rel. error = 0.99 %
# It 1,010: Loss = 4.3613e-03, Max. rel. error = 0.78 %
# It 1,020: Loss = 4.3414e-03, Max. rel. error = 0.85 %
# It 1,030: Loss = 4.3226e-03, Max. rel. error = 0.82 %
# It 1,040: Loss = 4.3031e-03, Max. rel. error = 0.53 %
# It 1,050: Loss = 4.4270e-03, Max. rel. error = 1.4 %
# Epoch  1059: reducing learning rate of group 0 to 1.0942e-03.
# It 1,060: Loss = 4.7917e-03, Max. rel. error = 43.04 %
# It 1,070: Loss = 4.3147e-03, Max. rel. error = 49.94 %
# It 1,080: Loss = 4.2388e-03, Max. rel. error = 19.69 %
# It 1,090: Loss = 4.2227e-03, Max. rel. error = 2.12 %
# It 1,100: Loss = 4.2076e-03, Max. rel. error = 0.8 %
# It 1,110: Loss = 4.1915e-03, Max. rel. error = 0.73 %
# It 1,120: Loss = 4.1757e-03, Max. rel. error = 0.77 %
# It 1,130: Loss = 4.1587e-03, Max. rel. error = 0.73 %
# It 1,140: Loss = 4.1520e-03, Max. rel. error = 0.75 %
# It 1,150: Loss = 4.2906e-03, Max. rel. error = 0.95 %
# Epoch  1158: reducing learning rate of group 0 to 9.8477e-04.
# It 1,160: Loss = 4.4869e-03, Max. rel. error = 14.7 %
# It 1,170: Loss = 4.0995e-03, Max. rel. error = 29.27 %
# It 1,180: Loss = 4.0847e-03, Max. rel. error = 9.79 %
# It 1,190: Loss = 4.0706e-03, Max. rel. error = 0.81 %
# It 1,200: Loss = 4.0565e-03, Max. rel. error = 0.64 %
# It 1,210: Loss = 4.0428e-03, Max. rel. error = 0.66 %
# It 1,220: Loss = 4.0285e-03, Max. rel. error = 0.66 %
# It 1,230: Loss = 4.0146e-03, Max. rel. error = 0.65 %
# It 1,240: Loss = 4.0023e-03, Max. rel. error = 1.08 %
# It 1,250: Loss = 4.7282e-03, Max. rel. error = 11.55 %
# Epoch  1252: reducing learning rate of group 0 to 8.8629e-04.
# It 1,260: Loss = 4.0573e-03, Max. rel. error = 39.83 %
# It 1,270: Loss = 3.9624e-03, Max. rel. error = 48.42 %
# It 1,280: Loss = 3.9497e-03, Max. rel. error = 2.68 %
# It 1,290: Loss = 3.9372e-03, Max. rel. error = 0.67 %
# It 1,300: Loss = 3.9248e-03, Max. rel. error = 0.61 %
# It 1,310: Loss = 3.9124e-03, Max. rel. error = 0.6 %
# It 1,320: Loss = 3.9000e-03, Max. rel. error = 0.61 %
# It 1,330: Loss = 3.8878e-03, Max. rel. error = 0.61 %
# It 1,340: Loss = 3.8933e-03, Max. rel. error = 0.6 %
# It 1,350: Loss = 4.4924e-03, Max. rel. error = 5.82 %
# Epoch  1356: reducing learning rate of group 0 to 7.9766e-04.
# It 1,360: Loss = 3.8919e-03, Max. rel. error = 27.96 %
# It 1,370: Loss = 3.8512e-03, Max. rel. error = 29.65 %
# It 1,380: Loss = 3.8285e-03, Max. rel. error = 3.33 %
# It 1,390: Loss = 3.8160e-03, Max. rel. error = 0.89 %
# It 1,400: Loss = 3.8041e-03, Max. rel. error = 0.61 %
# It 1,410: Loss = 3.7920e-03, Max. rel. error = 0.59 %
# It 1,420: Loss = 3.7801e-03, Max. rel. error = 0.54 %
# It 1,430: Loss = 3.7792e-03, Max. rel. error = 0.43 %
# It 1,440: Loss = 4.0411e-03, Max. rel. error = 4.27 %
# Epoch  1451: reducing learning rate of group 0 to 7.1790e-04.
# It 1,450: Loss = 4.1645e-03, Max. rel. error = 15.16 %
# It 1,460: Loss = 3.7339e-03, Max. rel. error = 17.13 %
# It 1,470: Loss = 3.7167e-03, Max. rel. error = 12.02 %
# It 1,480: Loss = 3.7037e-03, Max. rel. error = 0.79 %
# It 1,490: Loss = 3.6914e-03, Max. rel. error = 0.65 %
# It 1,500: Loss = 3.6795e-03, Max. rel. error = 0.62 %
# It 1,510: Loss = 3.6672e-03, Max. rel. error = 0.63 %
# It 1,520: Loss = 3.6567e-03, Max. rel. error = 0.58 %
# It 1,530: Loss = 3.6451e-03, Max. rel. error = 0.89 %
# It 1,540: Loss = 4.0194e-03, Max. rel. error = 6.45 %
# Epoch  1549: reducing learning rate of group 0 to 6.4611e-04.
# It 1,550: Loss = 3.6246e-03, Max. rel. error = 16.75 %
# It 1,560: Loss = 3.6105e-03, Max. rel. error = 18.03 %
# It 1,570: Loss = 3.5983e-03, Max. rel. error = 1.33 %
# It 1,580: Loss = 3.5862e-03, Max. rel. error = 0.65 %
# It 1,590: Loss = 3.5748e-03, Max. rel. error = 0.63 %
# It 1,600: Loss = 3.5637e-03, Max. rel. error = 0.6 %
# It 1,610: Loss = 3.5529e-03, Max. rel. error = 0.59 %
# It 1,620: Loss = 3.5421e-03, Max. rel. error = 0.58 %
# It 1,630: Loss = 3.5445e-03, Max. rel. error = 0.51 %
# It 1,640: Loss = 3.7292e-03, Max. rel. error = 2.55 %
# It 1,650: Loss = 3.5332e-03, Max. rel. error = 13.3 %
# It 1,660: Loss = 3.5019e-03, Max. rel. error = 19.6 %
# It 1,670: Loss = 3.4905e-03, Max. rel. error = 2.43 %
# It 1,680: Loss = 3.4902e-03, Max. rel. error = 0.56 %
# It 1,690: Loss = 3.5157e-03, Max. rel. error = 5.62 %
# Epoch  1698: reducing learning rate of group 0 to 5.8150e-04.
# It 1,700: Loss = 3.6294e-03, Max. rel. error = 10.17 %
# It 1,710: Loss = 3.4546e-03, Max. rel. error = 20.54 %
# It 1,720: Loss = 3.4453e-03, Max. rel. error = 5.32 %
# It 1,730: Loss = 3.4365e-03, Max. rel. error = 0.57 %
# It 1,740: Loss = 3.4280e-03, Max. rel. error = 0.48 %
# It 1,750: Loss = 3.4196e-03, Max. rel. error = 0.47 %
# It 1,760: Loss = 3.4112e-03, Max. rel. error = 0.47 %
# It 1,770: Loss = 3.4028e-03, Max. rel. error = 0.47 %
# It 1,780: Loss = 3.3945e-03, Max. rel. error = 0.46 %
# It 1,790: Loss = 3.3919e-03, Max. rel. error = 0.44 %
# It 1,800: Loss = 3.4268e-03, Max. rel. error = 3.84 %
# Epoch  1808: reducing learning rate of group 0 to 5.2335e-04.
# It 1,810: Loss = 3.4227e-03, Max. rel. error = 11.84 %
# It 1,820: Loss = 3.3635e-03, Max. rel. error = 16.16 %
# It 1,830: Loss = 3.3564e-03, Max. rel. error = 1.95 %
# It 1,840: Loss = 3.3490e-03, Max. rel. error = 0.59 %
# It 1,850: Loss = 3.3419e-03, Max. rel. error = 0.41 %
# It 1,860: Loss = 3.3348e-03, Max. rel. error = 0.4 %
# It 1,870: Loss = 3.3277e-03, Max. rel. error = 0.39 %
# It 1,880: Loss = 3.3206e-03, Max. rel. error = 0.41 %
# It 1,890: Loss = 3.3134e-03, Max. rel. error = 0.41 %
# It 1,900: Loss = 3.3116e-03, Max. rel. error = 0.3 %
# It 1,910: Loss = 3.5233e-03, Max. rel. error = 2.63 %
# Epoch  1917: reducing learning rate of group 0 to 4.7101e-04.
# It 1,920: Loss = 3.3622e-03, Max. rel. error = 15.81 %
# It 1,930: Loss = 3.2901e-03, Max. rel. error = 20.66 %
# It 1,940: Loss = 3.2807e-03, Max. rel. error = 2.53 %
# It 1,950: Loss = 3.2748e-03, Max. rel. error = 0.47 %
# It 1,960: Loss = 3.2688e-03, Max. rel. error = 0.35 %
# It 1,970: Loss = 3.2627e-03, Max. rel. error = 0.35 %
# It 1,980: Loss = 3.2567e-03, Max. rel. error = 0.35 %
# It 1,990: Loss = 3.2503e-03, Max. rel. error = 0.36 %
# It 2,000: Loss = 3.2444e-03, Max. rel. error = 0.37 %
# It 2,010: Loss = 3.2378e-03, Max. rel. error = 0.34 %
# It 2,020: Loss = 3.2337e-03, Max. rel. error = 0.37 %
# It 2,030: Loss = 3.2265e-03, Max. rel. error = 0.96 %
# It 2,040: Loss = 3.6791e-03, Max. rel. error = 17.49 %
# Epoch  2042: reducing learning rate of group 0 to 4.2391e-04.
# It 2,050: Loss = 3.2181e-03, Max. rel. error = 17.71 %
# It 2,060: Loss = 3.2095e-03, Max. rel. error = 14.62 %
# It 2,070: Loss = 3.2034e-03, Max. rel. error = 0.53 %
# It 2,080: Loss = 3.1978e-03, Max. rel. error = 0.35 %
# It 2,090: Loss = 3.1923e-03, Max. rel. error = 0.33 %
# It 2,100: Loss = 3.1866e-03, Max. rel. error = 0.33 %
# It 2,110: Loss = 3.1810e-03, Max. rel. error = 0.34 %
# It 2,120: Loss = 3.1752e-03, Max. rel. error = 0.34 %
# It 2,130: Loss = 3.1711e-03, Max. rel. error = 0.32 %
# It 2,140: Loss = 3.1741e-03, Max. rel. error = 0.25 %
# It 2,150: Loss = 3.2504e-03, Max. rel. error = 3.34 %
# Epoch  2156: reducing learning rate of group 0 to 3.8152e-04.
# It 2,160: Loss = 3.1601e-03, Max. rel. error = 5.73 %
# It 2,170: Loss = 3.1485e-03, Max. rel. error = 6.45 %
# It 2,180: Loss = 3.1420e-03, Max. rel. error = 0.85 %
# It 2,190: Loss = 3.1370e-03, Max. rel. error = 0.37 %
# It 2,200: Loss = 3.1312e-03, Max. rel. error = 0.33 %
# It 2,210: Loss = 3.1253e-03, Max. rel. error = 0.35 %
# It 2,220: Loss = 3.1201e-03, Max. rel. error = 0.34 %
# It 2,230: Loss = 3.1146e-03, Max. rel. error = 0.33 %
# It 2,240: Loss = 3.1107e-03, Max. rel. error = 0.31 %
# It 2,250: Loss = 3.1669e-03, Max. rel. error = 0.99 %
# Epoch  2257: reducing learning rate of group 0 to 3.4337e-04.
# It 2,260: Loss = 3.1124e-03, Max. rel. error = 5.44 %
# It 2,270: Loss = 3.0952e-03, Max. rel. error = 6.51 %
# It 2,280: Loss = 3.0895e-03, Max. rel. error = 1.12 %
# It 2,290: Loss = 3.0849e-03, Max. rel. error = 0.32 %
# It 2,300: Loss = 3.0802e-03, Max. rel. error = 0.29 %
# It 2,310: Loss = 3.0756e-03, Max. rel. error = 0.29 %
# It 2,320: Loss = 3.0710e-03, Max. rel. error = 0.29 %
# It 2,330: Loss = 3.0662e-03, Max. rel. error = 0.28 %
# It 2,340: Loss = 3.0667e-03, Max. rel. error = 0.26 %
# It 2,350: Loss = 3.0937e-03, Max. rel. error = 0.52 %
# It 2,360: Loss = 3.0985e-03, Max. rel. error = 4.12 %
# It 2,370: Loss = 3.0497e-03, Max. rel. error = 7.4 %
# It 2,380: Loss = 3.0438e-03, Max. rel. error = 2.15 %
# It 2,390: Loss = 3.0388e-03, Max. rel. error = 0.37 %
# It 2,400: Loss = 3.0370e-03, Max. rel. error = 0.29 %
# It 2,410: Loss = 3.0312e-03, Max. rel. error = 0.69 %
# Epoch  2420: reducing learning rate of group 0 to 3.0903e-04.
# It 2,420: Loss = 3.2098e-03, Max. rel. error = 9.23 %
# It 2,430: Loss = 3.0239e-03, Max. rel. error = 9.67 %
# It 2,440: Loss = 3.0181e-03, Max. rel. error = 6.35 %
# It 2,450: Loss = 3.0138e-03, Max. rel. error = 0.32 %
# It 2,460: Loss = 3.0098e-03, Max. rel. error = 0.26 %
# It 2,470: Loss = 3.0056e-03, Max. rel. error = 0.26 %
# It 2,480: Loss = 3.0016e-03, Max. rel. error = 0.26 %
# It 2,490: Loss = 2.9976e-03, Max. rel. error = 0.26 %
# It 2,500: Loss = 2.9935e-03, Max. rel. error = 0.26 %
# It 2,510: Loss = 2.9895e-03, Max. rel. error = 0.26 %
# It 2,520: Loss = 2.9856e-03, Max. rel. error = 0.24 %
# It 2,530: Loss = 2.9851e-03, Max. rel. error = 0.65 %
# Epoch  2538: reducing learning rate of group 0 to 2.7813e-04.
# It 2,540: Loss = 2.9841e-03, Max. rel. error = 4.1 %
# It 2,550: Loss = 2.9765e-03, Max. rel. error = 5.07 %
# It 2,560: Loss = 2.9703e-03, Max. rel. error = 0.84 %
# It 2,570: Loss = 2.9669e-03, Max. rel. error = 0.31 %
# It 2,580: Loss = 2.9632e-03, Max. rel. error = 0.23 %
# It 2,590: Loss = 2.9596e-03, Max. rel. error = 0.23 %
# It 2,600: Loss = 2.9560e-03, Max. rel. error = 0.23 %
# It 2,610: Loss = 2.9524e-03, Max. rel. error = 0.23 %
# It 2,620: Loss = 2.9487e-03, Max. rel. error = 0.23 %
# It 2,630: Loss = 2.9450e-03, Max. rel. error = 0.23 %
# It 2,640: Loss = 2.9473e-03, Max. rel. error = 0.22 %
# It 2,650: Loss = 3.0014e-03, Max. rel. error = 2.23 %
# Epoch  2653: reducing learning rate of group 0 to 2.5032e-04.
# It 2,660: Loss = 2.9373e-03, Max. rel. error = 6.59 %
# It 2,670: Loss = 2.9319e-03, Max. rel. error = 6.89 %
# It 2,680: Loss = 2.9280e-03, Max. rel. error = 0.38 %
# It 2,690: Loss = 2.9248e-03, Max. rel. error = 0.23 %
# It 2,700: Loss = 2.9216e-03, Max. rel. error = 0.21 %
# It 2,710: Loss = 2.9183e-03, Max. rel. error = 0.21 %
# It 2,720: Loss = 2.9151e-03, Max. rel. error = 0.21 %
# It 2,730: Loss = 2.9118e-03, Max. rel. error = 0.21 %
# It 2,740: Loss = 2.9085e-03, Max. rel. error = 0.22 %
# It 2,750: Loss = 2.9052e-03, Max. rel. error = 0.22 %
# It 2,760: Loss = 2.9019e-03, Max. rel. error = 0.2 %
# It 2,770: Loss = 2.8994e-03, Max. rel. error = 0.27 %
# Epoch  2780: reducing learning rate of group 0 to 2.2528e-04.
# It 2,780: Loss = 3.0007e-03, Max. rel. error = 2.56 %
# It 2,790: Loss = 2.8924e-03, Max. rel. error = 3.71 %
# It 2,800: Loss = 2.8894e-03, Max. rel. error = 3.85 %
# It 2,810: Loss = 2.8864e-03, Max. rel. error = 0.24 %
# It 2,820: Loss = 2.8834e-03, Max. rel. error = 0.2 %
# It 2,830: Loss = 2.8804e-03, Max. rel. error = 0.2 %
# It 2,840: Loss = 2.8774e-03, Max. rel. error = 0.2 %
# It 2,850: Loss = 2.8744e-03, Max. rel. error = 0.2 %
# It 2,860: Loss = 2.8713e-03, Max. rel. error = 0.2 %
# It 2,870: Loss = 2.8684e-03, Max. rel. error = 0.2 %
# It 2,880: Loss = 2.8654e-03, Max. rel. error = 0.19 %
# It 2,890: Loss = 2.8745e-03, Max. rel. error = 0.43 %
# Epoch  2896: reducing learning rate of group 0 to 2.0276e-04.
# It 2,900: Loss = 2.8710e-03, Max. rel. error = 3.61 %
# It 2,910: Loss = 2.8569e-03, Max. rel. error = 3.89 %
# It 2,920: Loss = 2.8538e-03, Max. rel. error = 0.62 %
# It 2,930: Loss = 2.8510e-03, Max. rel. error = 0.2 %
# It 2,940: Loss = 2.8483e-03, Max. rel. error = 0.18 %
# It 2,950: Loss = 2.8455e-03, Max. rel. error = 0.18 %
# It 2,960: Loss = 2.8427e-03, Max. rel. error = 0.18 %
# It 2,970: Loss = 2.8399e-03, Max. rel. error = 0.19 %
# It 2,980: Loss = 2.8371e-03, Max. rel. error = 0.19 %
# It 2,990: Loss = 2.8343e-03, Max. rel. error = 0.19 %
# It 3,000: Loss = 2.8316e-03, Max. rel. error = 0.19 %
#
# Runtime: 74.703 minutes

# %%
solver.plot_loss_history()
# Out:
# <Axes: xlabel='$n_{epoch}$', ylabel='$loss$'>

# %%
model.eval()
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
colors = ['tab:red', 'tab:orange', '#f9c74f', 'tab:green', 'tab:cyan', 'tab:blue', 'tab:purple', 'tab:brown', 'tab:pink']

fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
def denorm(normalized_vectors, lb, ub):
    original_vectors = normalized_vectors * (ub - lb) + lb
    return original_vectors

N=df_hf['n'].unique()
for i, value in enumerate(N):
    test_data=df_hf[df_hf.n==value]
    
    # 计算等间隔的索引
    num_points = len(test_data)
    step = max(1, num_points // 1000)  # 确保步长至少为1
    sampled_indices = range(0, num_points//2, step)
    
    # 按等间隔取点
    sampled_test_data = test_data.iloc[sampled_indices]

    x1_test = torch.tensor(sampled_test_data['Strain'].values, dtype=torch.float32).view(-1, 1)
    x2_test = torch.tensor(sampled_test_data['n'].values, dtype=torch.float32).view(-1, 1)
    x3_test = torch.tensor(sampled_test_data['Time'].values, dtype=torch.float32).view(-1, 1)
    y1_test = torch.tensor(sampled_test_data['Stress'].values, dtype=torch.float32).view(-1, 1)
    x1_test = norm(x1_test, lb[0], ub[0])
    x2_test = norm(x2_test, lb[1], ub[1])
    x3_test = norm(x3_test, lb[2], ub[2])
    y1_test = norm(y1_test, lb[3], ub[3]) 
    
    # 将 NumPy 数组转换为 PyTorch 张量
    X_MF = torch.cat([x1_test, x2_test,x3_test], dim=1)
    X_MF=create_dynamic_window(X_MF,time_steps)
    y_MF = model(X_MF) 
    # 反归一化 y_MF
    y_MF_denorm = denorm(y_MF.detach().numpy(), lb[3], ub[3])

     # 绘制数据
    ax.plot((denorm(x1_test[time_steps-1:],lb[0],ub[0])), y_MF_denorm, color=colors[i % len(colors)])
   
    if value == 1.5:
        ax.scatter(sampled_test_data['Strain'].values, sampled_test_data['Stress'].values, color=colors[i % len(colors)], marker='o', facecolors='none', 
                   label=f'n{i}(Test)',s=12)
    else:
       ax.scatter(sampled_test_data['Strain'].values, sampled_test_data['Stress'].values, color=colors[i % len(colors)], marker='o', 
                  label=f'n{i}',s=12)
       
    
    
# ax.axvspan(1, 100, color='gray', alpha=0.2) 突出标记
# ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_ylabel('$Stress$$\mathrm{[Pa]}$')
ax.set_xlabel('$Strain$')
# ax.grid()
# 调整图例的大小和位置
legend = ax.legend(fontsize=7.5, loc='lower right', bbox_to_anchor=(0.24, 0.81))
#ax.invert_xaxis()
plt.show()

# %%
model.eval()
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
colors = ['tab:red', 'tab:orange', '#f9c74f', 'tab:green', 'tab:cyan', 'tab:blue', 'tab:purple', 'tab:brown', 'tab:pink']

fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
def denorm(normalized_vectors, lb, ub):
    original_vectors = normalized_vectors * (ub - lb) + lb
    return original_vectors

N=df_hf['n'].unique()
R2 = 0
MAE = 0
MSE = 0
for i, value in enumerate(N):
    test_data=df_hf[df_hf.n==value]
    
    # 计算等间隔的索引
    num_points = len(test_data)
    step = max(1, num_points//1000)  # 确保步长至少为1
    sampled_indices = range(0, num_points, step)
    
    # 按等间隔取点
    sampled_test_data = test_data.iloc[sampled_indices]

    x1_test = torch.tensor(sampled_test_data['Strain'].values, dtype=torch.float32).view(-1, 1)
    x2_test = torch.tensor(sampled_test_data['n'].values, dtype=torch.float32).view(-1, 1)
    x3_test = torch.tensor(sampled_test_data['Time'].values, dtype=torch.float32).view(-1, 1)
    y1_test = torch.tensor(sampled_test_data['Stress'].values, dtype=torch.float32).view(-1, 1)
    x1_test = norm(x1_test, lb[0], ub[0])
    x2_test = norm(x2_test, lb[1], ub[1])
    x3_test = norm(x3_test, lb[2], ub[2])
    y1_test = norm(y1_test, lb[3], ub[3]) 
    
    # 将 NumPy 数组转换为 PyTorch 张量
    X_MF = torch.cat([x1_test, x2_test,x3_test], dim=1)
    X_MF=create_dynamic_window(X_MF,time_steps)
    y_MF = model(X_MF)
    # 反归一化 y_MF
    y_MF_denorm = denorm(y_MF.detach().numpy(), lb[3], ub[3])
     # 绘制数据
   
    if value == 1.5:
        ax.plot((denorm(x1_test[time_steps-1:],lb[0],ub[0])), y_MF_denorm, color=colors[3],label=f'Predict')
        ax.scatter(sampled_test_data['Strain'].values[time_steps+3:], sampled_test_data['Stress'].values[time_steps+3:], color=colors[5], marker='o', facecolors='none', 
                   label=f'(Test)',s=12)
        R2 = r2_score(y_MF_denorm, sampled_test_data['Stress'].values[time_steps-1:])
        MAE = mean_absolute_error(y_MF_denorm, sampled_test_data['Stress'].values[time_steps-1:])
        MSE = mean_squared_error(y_MF_denorm, sampled_test_data['Stress'].values[time_steps-1:])
        # 计算 MAPE
        def calculate_mape(y_true, y_pred):
        # 计算每个样本的绝对百分比误差
         absolute_percentage_error = np.abs((y_true - y_pred) / y_true)
        # 计算平均值并乘以 100 得到百分比
         mape = np.mean(absolute_percentage_error) 
         return mape

        MAPE = calculate_mape(test_data['Stress'].values, y_MF_denorm)
    
# ax.axvspan(1, 100, color='gray', alpha=0.2) 突出标记
# ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_ylabel('$Stress$$\mathrm{[Pa]}$')
ax.set_xlabel('$Strain$')
# ax.grid()
# 调整图例的大小和位置
legend = ax.legend(fontsize=7.5, loc='lower right', bbox_to_anchor=(0.26, 0.83))
ax.text(0.7, 0.6, f'LSTM:\nR²: {R2:.4f}\nMAE: {MAE:.4f}\nMAPE: {MAPE:.4f}', 
        transform=ax.transAxes, fontsize=8, verticalalignment='top', bbox=None,color='tab:blue')

#ax.invert_xaxis()
plt.show()

# %%
model.eval()
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
colors = ['tab:red', 'tab:orange', '#f9c74f', 'tab:green', 'tab:cyan', 'tab:blue', 'tab:purple', 'tab:brown', 'tab:pink']

fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
def denorm(normalized_vectors, lb, ub):
    original_vectors = normalized_vectors * (ub - lb) + lb
    return original_vectors

N=df_hf['n'].unique()
R2 = 0
MAE = 0
MSE = 0
for i, value in enumerate(N):
    test_data=df_hf[df_hf.n==value]
    
    # 计算等间隔的索引
    num_points = len(test_data)
    step = max(1, num_points//1000)  # 确保步长至少为1
    sampled_indices = range(0, num_points, step)
    
    # 按等间隔取点
    sampled_test_data = test_data.iloc[sampled_indices]

    x1_test = torch.tensor(sampled_test_data['Strain'].values, dtype=torch.float32).view(-1, 1)
    x2_test = torch.tensor(sampled_test_data['n'].values, dtype=torch.float32).view(-1, 1)
    x3_test = torch.tensor(sampled_test_data['Time'].values, dtype=torch.float32).view(-1, 1)
    y1_test = torch.tensor(sampled_test_data['Stress'].values, dtype=torch.float32).view(-1, 1)
    x1_test = norm(x1_test, lb[0], ub[0])
    x2_test = norm(x2_test, lb[1], ub[1])
    x3_test = norm(x3_test, lb[2], ub[2])
    y1_test = norm(y1_test, lb[3], ub[3]) 
    
    # 将 NumPy 数组转换为 PyTorch 张量
    X_MF = torch.cat([x1_test, x2_test,x3_test], dim=1)
    X_MF=create_dynamic_window(X_MF,time_steps)
    y_MF = model(X_MF)
    # 反归一化 y_MF
    y_MF_denorm = denorm(y_MF.detach().numpy(), lb[3], ub[3])
     # 绘制数据
   
    if value == 1.5:
        ax.plot((denorm(x3_test[time_steps-1:],lb[2],ub[2])), y_MF_denorm, color=colors[3],label=f'Predict')
        ax.scatter(sampled_test_data['Time'].values[time_steps+6:], sampled_test_data['Stress'].values[time_steps+6:], color=colors[5], marker='o', facecolors='none', 
                   label=f'(Test)',s=12)
    
# ax.axvspan(1, 100, color='gray', alpha=0.2) 突出标记
# ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_ylabel('$Stress$$\mathrm{[Pa]}$')
ax.set_xlabel('$Time[s]$')
# ax.grid()
# 调整图例的大小和位置
legend = ax.legend(fontsize=7.5, loc='lower right', bbox_to_anchor=(0.24, 0.85))

#ax.invert_xaxis()
plt.show()

# %%
torch.save(model.state_dict(), 'model/maxwell_lstm_sin_de_l.pth')
