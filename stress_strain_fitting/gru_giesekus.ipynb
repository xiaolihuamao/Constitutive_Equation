# %% [markdown]
# ## LSTM/GRU方法进行giekus模型的训练和预测

# %%
from time import time
from datetime import datetime
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import random, genfromtxt
from IPython.display import display
from matplotlib import rc
from matplotlib.pyplot import figure
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import StepLR
import torch.nn.functional as F
import matplotlib.ticker as mticker
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error 
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler

# %%
current_directory = os.getcwd()
print(current_directory)

# 检查是否有可用的 GPU
if torch.cuda.is_available():
    device = torch.device("cuda")  # 使用 GPU
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")  # 使用 CPU
    print("No GPU available, using CPU instead.")
# Out:
# /home/redfu/work/Constitutive_Equation/stress_strain_fitting
# Using GPU: NVIDIA GeForce RTX 2080 Ti

# %%
# 设置数据类型
DTYPE = torch.float32

# 设置随机种子
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)

df = {}
# 读取数据
url = 'data/giesekus_model_test_data.xlsx'

df = pd.read_excel(url, sheet_name=None)
data_HF = [[k, v] for k, v in df.items()]  # k is the sheet name, v is the pandas df
# 循环遍历 data_HF 列表并获取下标
data_train=pd.DataFrame()
data_valid=pd.DataFrame()
for i, (sheet_name, sheet_data) in enumerate(data_HF):
    if i==3:
        # 假设 sheet_data 是一个 DataFrame
        half_length = len(sheet_data) // 5
        sheet_data = sheet_data.iloc[:half_length]
        data_valid=sheet_data   
        data_train=pd.concat([data_train, sheet_data], ignore_index=True)

df_hf = pd.concat([data_train, data_valid], ignore_index=True)
x1_np=data_train['Time'].values
x2_np=data_train['γd12'].values
y1_np=data_train['σ11'].values
y2_np=data_train['σ22'].values
y3_np=data_train['σ12'].values
data_np = np.stack((x1_np, x2_np, y1_np, y2_np, y3_np), axis=1)

# 初始化 MinMaxScaler
scaler = MinMaxScaler()
# 对数据进行归一化
data_normalized = scaler.fit_transform(data_np)
# 分离归一化后的数据
x1_normalized = data_normalized[:, 0]
x2_normalized = data_normalized[:, 1]
y1_normalized = data_normalized[:, 2]
y2_normalized = data_normalized[:, 3]
y3_normalized = data_normalized[:, 4]

# 将归一化后的数据转换为 PyTorch 张量
x1_d_HF = torch.tensor(x1_normalized, dtype=torch.float32).view(-1, 1)
x2_d_HF = torch.tensor(x2_normalized, dtype=torch.float32).view(-1, 1)
y1_d_HF = torch.tensor(y1_normalized, dtype=torch.float32).view(-1, 1)
y2_d_HF = torch.tensor(y2_normalized, dtype=torch.float32).view(-1, 1)
y3_d_HF = torch.tensor(y3_normalized, dtype=torch.float32).view(-1, 1)

# 合并数据
X_data_HF = torch.cat([x1_d_HF, x2_d_HF], dim=1)
y_data_HF = torch.cat([y1_d_HF,y2_d_HF,y3_d_HF], dim=1)  
# 合并 X_data_HF 和 y_data_HF
Xy_data_HF = torch.cat([X_data_HF, y_data_HF], dim=1)

# 打印结果
print("X_data_HF shape:", X_data_HF.shape)
print("y_data_HF shape:", y_data_HF.shape)
print("Xy_data_HF shape:", Xy_data_HF.shape)

# 定义模型
in_dim, out_dim = 2, 3
# Out:
# X_data_HF shape: torch.Size([200, 2])
# y_data_HF shape: torch.Size([200, 3])
# Xy_data_HF shape: torch.Size([200, 5])

# %% [markdown]
# ### 通过滑动窗口构建序列数据

# %%
# 定义时间步长
time_steps = 1
# 动态窗口实现
def create_dynamic_window(data, time_steps):
    """
    通过动态窗口将数据调整为适合 LSTM 输入的格式。
    :param data: 输入数据，形状为 (num_samples, ...)
    :param time_steps: 时间步长
    :return: 调整后的数据，形状为 (num_samples - time_steps + 1, time_steps, ...)
    """
    num_samples = data.shape[0]
    if num_samples < time_steps:
        raise ValueError("样本数量必须大于等于时间步长")
    
    # 创建动态窗口
    windowed_data = []
    for i in range(num_samples - time_steps+1):
        window = data[i:i + time_steps]
        windowed_data.append(window)
    
    return torch.stack(windowed_data)

# 调整 X_data_HF
X_data_HF = create_dynamic_window(X_data_HF, time_steps)

# 调整 y_data_HF
# 注意：y_data_HF 通常是目标值，只需要取最后一个时间步的值
y_data_HF = y_data_HF[time_steps-1:]
print(X_data_HF.shape)
print(y_data_HF.shape)
# Out:
# torch.Size([200, 1, 2])
# torch.Size([200, 3])

# %%
# 验证集数据
x1_valid_np=data_valid['Time'].values
x2_valid_np=data_valid['γd12'].values
y1_valid_np=data_valid['σ11'].values
y2_valid_np=data_valid['σ22'].values
y3_valid_np=data_valid['σ12'].values
# 将验证集数据组合成一个二维数组
valid_data_np = np.stack((x1_valid_np, x2_valid_np, y1_valid_np,y2_valid_np,y3_valid_np), axis=1)
# 使用训练集的 scaler 对验证集数据进行归一化
valid_data_normalized = scaler.transform(valid_data_np)
# 分离归一化后的验证集数据
x1_valid_normalized = valid_data_normalized[:, 0]
x2_valid_normalized = valid_data_normalized[:, 1]
y1_valid_normalized = valid_data_normalized[:, 2]
y2_valid_normalized = valid_data_normalized[:, 3]
y3_valid_normalized = valid_data_normalized[:, 4]
# 将归一化后的验证集数据转换为 PyTorch 张量
x1_d_valid = torch.tensor(x1_valid_normalized, dtype=torch.float32).view(-1, 1)
x2_d_valid = torch.tensor(x2_valid_normalized, dtype=torch.float32).view(-1, 1)
y1_d_valid = torch.tensor(y1_valid_normalized, dtype=torch.float32).view(-1, 1)
y2_d_valid = torch.tensor(y2_valid_normalized, dtype=torch.float32).view(-1, 1)
y3_d_valid = torch.tensor(y3_valid_normalized, dtype=torch.float32).view(-1, 1)

# 合并数据
X_data_valid = torch.cat([x1_d_valid, x2_d_valid], dim=1)
y_data_valid = torch.cat([y1_d_valid,y2_d_valid,y3_d_valid], dim=1)

# %%
# 调整 X_data_valid
X_data_valid = create_dynamic_window(X_data_valid, time_steps)
# 调整 y_data_HF
# 注意：y_data_HF 通常是目标值，只需要取最后一个时间步的值
y_data_valid = y_data_valid[time_steps-1:]
print(X_data_valid.shape)
print(y_data_valid.shape)
# Out:
# torch.Size([200, 1, 2])
# torch.Size([200, 3])

# %%
class GRU_NeuralNet(nn.Module):
    """ Set basic architecture of the PINN model using GRU."""

    def __init__(self,
                 input_dim=0,
                 output_dim=1,  # 默认输出维度为1
                 hidden_size=20,  # GRU 隐藏层的维度
                 num_layers=4,    # GRU 层数
                 activation='tanh',
                 kernel_initializer='glorot_normal',
                 **kwargs):
        super(GRU_NeuralNet, self).__init__()

        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_dim = output_dim

        # 添加 GRU 层
        self.gru = nn.GRU(input_dim, hidden_size, num_layers, batch_first=True)
        
        # 添加第一层全连接层（从 GRU 的隐藏状态映射到中间层）
        self.fc1 = nn.Linear(hidden_size, hidden_size)  # 中间层的维度可以与 hidden_size 相同
        
        # 添加第二层全连接层（从中间层映射到输出维度）
        self.out = nn.Linear(hidden_size, output_dim)
        
        # 设置激活函数
        if activation == 'tanh':
            self.activation = torch.tanh
        elif activation == 'relu':
            self.activation = F.relu6
        elif activation == 'sigmoid':
            self.activation = torch.sigmoid
        elif activation == 'linear':
            self.activation = None
        else:
            raise ValueError("Unsupported activation function")
        
        # 初始化权重
        if kernel_initializer == 'glorot_normal':
            for name, param in self.gru.named_parameters():
                if 'weight' in name:
                    nn.init.xavier_normal_(param)
            nn.init.xavier_normal_(self.fc1.weight)
            nn.init.xavier_normal_(self.out.weight)
        elif kernel_initializer == 'glorot_uniform':
            for name, param in self.gru.named_parameters():
                if 'weight' in name:
                    nn.init.xavier_uniform_(param)
            nn.init.xavier_uniform_(self.fc1.weight)
            nn.init.xavier_uniform_(self.out.weight)
        else:
            raise ValueError("Unsupported kernel initializer")

    def forward(self, X):
        # GRU 输入形状: (batch_size, seq_len, input_dim)
        # GRU 输出形状: (batch_size, seq_len, hidden_size)
        # 初始化隐藏状态
        h0 = torch.zeros(self.num_layers, X.size(0), self.hidden_size).to(X.device)
        
        # 通过 GRU 层
        gru_out, _ = self.gru(X, h0)
        
        # 取最后一个时间步的输出
        last_time_step = gru_out[:, -1, :]  # (batch_size, hidden_size)
        
        # 通过第一层全连接层
        Z = self.fc1(last_time_step)
        
        # 应用激活函数（如果需要）
        if self.activation is not None:
            Z = self.activation(Z)
        
        # 通过第二层全连接层
        Z = self.out(Z)
        
        return Z

# %%
# 神经网络处理器类
class PINNSolver():

    # 类属性定义
    def __init__(self, model):
        self.model = model # 
        # Initialize history of losses and global iteration counter
        self.hist =  [[], []] # loss历史列表,0:train loss ;1:valid loss
        self.iter = 0 # 迭代次数
        self.last_n_losses = [] # 前损失列表

    # 更新损失列表   
    def update_last_n_losses(self, loss):
        self.last_n_losses.append(loss)
        if len(self.last_n_losses) > 20:
            self.last_n_losses.pop(0)

    # 计算最大相对误差        
    def ES(self):
        if len(self.last_n_losses) < 20:
            return 100  # a large number

        current_loss = self.last_n_losses[-1]
        max_relative_error = 100.*max([abs(current_loss - loss) / current_loss for loss in self.last_n_losses[:-1]])
        return max_relative_error
    
    # 计算loss，模型核心
    def loss_fn(self, X_data_HF, y_data_HF,X_data_valid,y_data_valid):
        y_pred_valid = self.model(X_data_valid)    
    
        y_pred_HF = self.model(X_data_HF)

        Loss_L2 = 1e-5 * sum(torch.sum(w_**2) for w_ in self.model.parameters())
        # 计算高频数据集的 Huber Loss
        Loss_data_HF = F.smooth_l1_loss(y_pred_HF[:,2], y_data_HF[:,2]) 
    
        # 计算验证集的 Huber Loss
        Loss_data_valid = F.smooth_l1_loss(y_pred_valid[:,2], y_data_valid[:,2]) 
        return Loss_data_HF,Loss_data_valid
    
    # 训练核心函数，包括loss计算梯度计算和反向传播
    def solve_with_PyTorch_optimizer(self, optimizer, data, scheduler, batch_size, N=1001):
        """This method performs a gradient descent type optimization."""
        # 解包数据
        X_data_HF, y_data_HF, X_data_valid, y_data_valid = data

        # 创建训练数据集和 DataLoader
        train_dataset = TensorDataset(X_data_HF, y_data_HF)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
        for i in range(N):
            # 初始化 epoch 的总损失
            epoch_loss_sum = 0.0
            num_batches = 0
            # 遍历每个批次
            for X_batch, y_batch in train_loader:
                # 梯度清0
                optimizer.zero_grad()
                # 计算 loss
                loss, _ = self.loss_fn(X_batch, y_batch, X_data_valid, y_data_valid)

                # 反向传播计算梯度
                loss.backward()

                # 反向传播更新权重和偏置
                optimizer.step()

                # 累加每个批次的损失
                epoch_loss_sum += loss.item()
                num_batches += 1

            # 计算 epoch 的平均损失
            # 在整个验证集上计算验证损失
            loss_train, loss_valid = self.loss_fn(X_data_HF, y_data_HF, X_data_valid, y_data_valid)

            # 记录 epoch 的平均损失
            self.current_loss = loss_train.item()
            self.valid_loss = loss_valid.item()
            # 根据 epoch 的平均损失调度学习率
            scheduler.step(loss_train)
            
            # 计算相对误差
            self.max_relative_error = self.ES()
            self.callback(self.max_relative_error, N)  # 将 max_relative_error 传递给回调函数
            self.update_last_n_losses(self.current_loss)

            # 早停机制
            if self.max_relative_error < 2e-3:  # 以 % 为单位
                print('Early stopping... \nIt {:05,d}: Loss = {:10.4e}, Max. rel. error = {} %'.format(self.iter,
                                                                                                    self.current_loss,
                                                                                                    np.round(self.max_relative_error, 3)))
                break
    # 打印loss    
    def callback(self, xr=None,N=1001):
        if self.iter % 10 == 0:
            print('It {:05,d}: Loss = {:10.4e}, Max. rel. error = {} %'.format(self.iter,
                                                             self.current_loss,
                                                            np.round(self.max_relative_error, 2)))
        self.hist[0].append(self.current_loss)
        self.hist[1].append(self.valid_loss)
        self.iter+=1
    
    def plot_loss_history(self, ax=None):
        if not ax:
            fig = plt.figure(figsize=(7, 5))
            ax = fig.add_subplot(111)

        # 绘制训练集损失曲线
        ax.semilogy(range(len(self.hist[0])), self.hist[0], 'b-', label='Training Loss')
        
        # 绘制验证集损失曲线
        ax.semilogy(range(len(self.hist[1])), self.hist[1], 'g-', label='Validation Loss')

        ax.set_xlabel('$n_{epoch}$')
        ax.set_ylabel('$loss$')
        ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, pos: f'{int(x):,}'))
        ax.legend()  # 添加图例
        return ax

# %%
model= GRU_NeuralNet(input_dim=in_dim,
                             output_dim=out_dim,
                             num_layers=4,
                             hidden_size=10,
                             activation='relu')

# 初始化 PINNSolver
solver = PINNSolver(model)
model = model.to(device)  # 将模型移动到 GPU
X_data_HF,y_data_HF,X_data_valid,y_data_valid
# 假设 X_data_HF, y_data_HF, X_data_valid, y_data_valid 是 PyTorch 张量
X_data_HF = X_data_HF.to(device)  # 将训练集输入数据移动到 GPU
y_data_HF = y_data_HF.to(device)  # 将训练集标签数据移动到 GPU

X_data_valid = X_data_valid.to(device)  # 将验证集输入数据移动到 GPU
y_data_valid = y_data_valid.to(device)  # 将验证集标签数据移动到 GPU

# %%
# 定义学习率调度器
lr = 1e-4
optimizer = optim.Adam(list(model.parameters()), lr=lr)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
batch=50
# 定义训练模式
mode = 'PyTorch_optimizer'
N = int(3000) + 1  # 训练迭代次数

try:
    runtime
except NameError:
    runtime = 0.

if mode == 'PyTorch_optimizer':
    try:
        t0 = time()
        solver.solve_with_PyTorch_optimizer(optimizer, [X_data_HF,y_data_HF,X_data_valid,y_data_valid],scheduler,batch,N=N)
        runtime += (time() - t0) / 60.
        print('\nRuntime: {:.3f} minutes'.format(runtime))
    except KeyboardInterrupt:
        runtime += (time() - t0) / 60.
        print('\nRuntime: {:.3f} minutes'.format(runtime))
# Out:
# It 0,000: Loss = 5.4288e-01, Max. rel. error = 100 %
# /home/redfu/anaconda3/envs/PINN/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# It 0,010: Loss = 5.3226e-01, Max. rel. error = 100 %
# It 0,020: Loss = 5.2220e-01, Max. rel. error = 3.76 %
# It 0,030: Loss = 5.1265e-01, Max. rel. error = 3.63 %
# It 0,040: Loss = 5.0300e-01, Max. rel. error = 3.61 %
# It 0,050: Loss = 4.9405e-01, Max. rel. error = 3.6 %
# It 0,060: Loss = 4.8625e-01, Max. rel. error = 3.3 %
# It 0,070: Loss = 4.7945e-01, Max. rel. error = 2.89 %
# It 0,080: Loss = 4.7215e-01, Max. rel. error = 2.82 %
# It 0,090: Loss = 4.6428e-01, Max. rel. error = 3.09 %
# It 0,100: Loss = 4.5577e-01, Max. rel. error = 3.39 %
# It 0,110: Loss = 4.4650e-01, Max. rel. error = 3.76 %
# It 0,120: Loss = 4.3631e-01, Max. rel. error = 4.21 %
# It 0,130: Loss = 4.2505e-01, Max. rel. error = 4.76 %
# It 0,140: Loss = 4.1254e-01, Max. rel. error = 5.43 %
# It 0,150: Loss = 3.9860e-01, Max. rel. error = 6.24 %
# It 0,160: Loss = 3.8306e-01, Max. rel. error = 7.24 %
# It 0,170: Loss = 3.6574e-01, Max. rel. error = 8.45 %
# It 0,180: Loss = 3.4652e-01, Max. rel. error = 9.91 %
# It 0,190: Loss = 3.2539e-01, Max. rel. error = 11.65 %
# It 0,200: Loss = 3.0246e-01, Max. rel. error = 13.68 %
# It 0,210: Loss = 2.7795e-01, Max. rel. error = 16.02 %
# It 0,220: Loss = 2.5223e-01, Max. rel. error = 18.69 %
# It 0,230: Loss = 2.2581e-01, Max. rel. error = 21.66 %
# It 0,240: Loss = 1.9933e-01, Max. rel. error = 24.89 %
# It 0,250: Loss = 1.7345e-01, Max. rel. error = 28.3 %
# It 0,260: Loss = 1.4880e-01, Max. rel. error = 31.84 %
# It 0,270: Loss = 1.2591e-01, Max. rel. error = 35.4 %
# It 0,280: Loss = 1.0518e-01, Max. rel. error = 38.87 %
# It 0,290: Loss = 8.6877e-02, Max. rel. error = 42.12 %
# It 0,300: Loss = 7.1103e-02, Max. rel. error = 44.95 %
# It 0,310: Loss = 5.7841e-02, Max. rel. error = 47.11 %
# It 0,320: Loss = 4.6968e-02, Max. rel. error = 48.28 %
# It 0,330: Loss = 3.8281e-02, Max. rel. error = 48.09 %
# It 0,340: Loss = 3.1523e-02, Max. rel. error = 46.23 %
# It 0,350: Loss = 2.6410e-02, Max. rel. error = 42.55 %
# It 0,360: Loss = 2.2650e-02, Max. rel. error = 37.22 %
# It 0,370: Loss = 1.9965e-02, Max. rel. error = 30.79 %
# It 0,380: Loss = 1.8102e-02, Max. rel. error = 24.05 %
# It 0,390: Loss = 1.6848e-02, Max. rel. error = 17.78 %
# It 0,400: Loss = 1.6025e-02, Max. rel. error = 12.49 %
# It 0,410: Loss = 1.5500e-02, Max. rel. error = 8.4 %
# It 0,420: Loss = 1.5171e-02, Max. rel. error = 5.45 %
# It 0,430: Loss = 1.4969e-02, Max. rel. error = 3.44 %
# It 0,440: Loss = 1.4846e-02, Max. rel. error = 2.12 %
# It 0,450: Loss = 1.4773e-02, Max. rel. error = 1.29 %
# It 0,460: Loss = 1.4729e-02, Max. rel. error = 0.77 %
# It 0,470: Loss = 1.4703e-02, Max. rel. error = 0.46 %
# It 0,480: Loss = 1.4687e-02, Max. rel. error = 0.28 %
# It 0,490: Loss = 1.4676e-02, Max. rel. error = 0.17 %
# It 0,500: Loss = 1.4669e-02, Max. rel. error = 0.11 %
# It 0,510: Loss = 1.4664e-02, Max. rel. error = 0.08 %
# It 0,520: Loss = 1.4659e-02, Max. rel. error = 0.06 %
# It 0,530: Loss = 1.4655e-02, Max. rel. error = 0.05 %
# It 0,540: Loss = 1.4652e-02, Max. rel. error = 0.05 %
# It 0,550: Loss = 1.4648e-02, Max. rel. error = 0.05 %
# It 0,560: Loss = 1.4644e-02, Max. rel. error = 0.05 %
# It 0,570: Loss = 1.4641e-02, Max. rel. error = 0.05 %
# It 0,580: Loss = 1.4637e-02, Max. rel. error = 0.05 %
# It 0,590: Loss = 1.4633e-02, Max. rel. error = 0.05 %
# It 0,600: Loss = 1.4629e-02, Max. rel. error = 0.05 %
# It 0,610: Loss = 1.4625e-02, Max. rel. error = 0.05 %
# It 0,620: Loss = 1.4621e-02, Max. rel. error = 0.05 %
# It 0,630: Loss = 1.4617e-02, Max. rel. error = 0.05 %
# It 0,640: Loss = 1.4613e-02, Max. rel. error = 0.05 %
# It 0,650: Loss = 1.4608e-02, Max. rel. error = 0.06 %
# It 0,660: Loss = 1.4604e-02, Max. rel. error = 0.06 %
# It 0,670: Loss = 1.4599e-02, Max. rel. error = 0.06 %
# It 0,680: Loss = 1.4595e-02, Max. rel. error = 0.06 %
# It 0,690: Loss = 1.4590e-02, Max. rel. error = 0.06 %
# It 0,700: Loss = 1.4585e-02, Max. rel. error = 0.06 %
# It 0,710: Loss = 1.4580e-02, Max. rel. error = 0.06 %
# It 0,720: Loss = 1.4575e-02, Max. rel. error = 0.07 %
# It 0,730: Loss = 1.4569e-02, Max. rel. error = 0.07 %
# It 0,740: Loss = 1.4564e-02, Max. rel. error = 0.07 %
# It 0,750: Loss = 1.4559e-02, Max. rel. error = 0.07 %
# It 0,760: Loss = 1.4553e-02, Max. rel. error = 0.07 %
# It 0,770: Loss = 1.4547e-02, Max. rel. error = 0.07 %
# It 0,780: Loss = 1.4541e-02, Max. rel. error = 0.08 %
# It 0,790: Loss = 1.4535e-02, Max. rel. error = 0.08 %
# It 0,800: Loss = 1.4529e-02, Max. rel. error = 0.08 %
# It 0,810: Loss = 1.4523e-02, Max. rel. error = 0.08 %
# It 0,820: Loss = 1.4516e-02, Max. rel. error = 0.08 %
# It 0,830: Loss = 1.4510e-02, Max. rel. error = 0.09 %
# It 0,840: Loss = 1.4503e-02, Max. rel. error = 0.09 %
# It 0,850: Loss = 1.4496e-02, Max. rel. error = 0.09 %
# It 0,860: Loss = 1.4489e-02, Max. rel. error = 0.09 %
# It 0,870: Loss = 1.4481e-02, Max. rel. error = 0.09 %
# It 0,880: Loss = 1.4474e-02, Max. rel. error = 0.1 %
# It 0,890: Loss = 1.4466e-02, Max. rel. error = 0.1 %
# It 0,900: Loss = 1.4459e-02, Max. rel. error = 0.1 %
# It 0,910: Loss = 1.4451e-02, Max. rel. error = 0.1 %
# It 0,920: Loss = 1.4442e-02, Max. rel. error = 0.11 %
# It 0,930: Loss = 1.4434e-02, Max. rel. error = 0.11 %
# It 0,940: Loss = 1.4425e-02, Max. rel. error = 0.11 %
# It 0,950: Loss = 1.4417e-02, Max. rel. error = 0.11 %
# It 0,960: Loss = 1.4408e-02, Max. rel. error = 0.12 %
# It 0,970: Loss = 1.4398e-02, Max. rel. error = 0.12 %
# It 0,980: Loss = 1.4389e-02, Max. rel. error = 0.12 %
# It 0,990: Loss = 1.4379e-02, Max. rel. error = 0.13 %
# It 1,000: Loss = 1.4369e-02, Max. rel. error = 0.13 %
# It 1,010: Loss = 1.4359e-02, Max. rel. error = 0.13 %
# It 1,020: Loss = 1.4349e-02, Max. rel. error = 0.14 %
# It 1,030: Loss = 1.4338e-02, Max. rel. error = 0.14 %
# It 1,040: Loss = 1.4327e-02, Max. rel. error = 0.14 %
# It 1,050: Loss = 1.4316e-02, Max. rel. error = 0.15 %
# It 1,060: Loss = 1.4305e-02, Max. rel. error = 0.15 %
# It 1,070: Loss = 1.4293e-02, Max. rel. error = 0.15 %
# It 1,080: Loss = 1.4281e-02, Max. rel. error = 0.16 %
# It 1,090: Loss = 1.4269e-02, Max. rel. error = 0.16 %
# It 1,100: Loss = 1.4256e-02, Max. rel. error = 0.17 %
# It 1,110: Loss = 1.4243e-02, Max. rel. error = 0.17 %
# It 1,120: Loss = 1.4230e-02, Max. rel. error = 0.17 %
# It 1,130: Loss = 1.4216e-02, Max. rel. error = 0.18 %
# It 1,140: Loss = 1.4202e-02, Max. rel. error = 0.18 %
# It 1,150: Loss = 1.4188e-02, Max. rel. error = 0.19 %
# It 1,160: Loss = 1.4173e-02, Max. rel. error = 0.19 %
# It 1,170: Loss = 1.4158e-02, Max. rel. error = 0.2 %
# It 1,180: Loss = 1.4143e-02, Max. rel. error = 0.2 %
# It 1,190: Loss = 1.4127e-02, Max. rel. error = 0.21 %
# It 1,200: Loss = 1.4111e-02, Max. rel. error = 0.21 %
# It 1,210: Loss = 1.4095e-02, Max. rel. error = 0.22 %
# It 1,220: Loss = 1.4078e-02, Max. rel. error = 0.23 %
# It 1,230: Loss = 1.4060e-02, Max. rel. error = 0.23 %
# It 1,240: Loss = 1.4042e-02, Max. rel. error = 0.24 %
# It 1,250: Loss = 1.4024e-02, Max. rel. error = 0.25 %
# It 1,260: Loss = 1.4005e-02, Max. rel. error = 0.25 %
# It 1,270: Loss = 1.3986e-02, Max. rel. error = 0.26 %
# It 1,280: Loss = 1.3966e-02, Max. rel. error = 0.27 %
# It 1,290: Loss = 1.3945e-02, Max. rel. error = 0.27 %
# It 1,300: Loss = 1.3924e-02, Max. rel. error = 0.28 %
# It 1,310: Loss = 1.3903e-02, Max. rel. error = 0.29 %
# It 1,320: Loss = 1.3880e-02, Max. rel. error = 0.3 %
# It 1,330: Loss = 1.3858e-02, Max. rel. error = 0.31 %
# It 1,340: Loss = 1.3834e-02, Max. rel. error = 0.32 %
# It 1,350: Loss = 1.3810e-02, Max. rel. error = 0.33 %
# It 1,360: Loss = 1.3785e-02, Max. rel. error = 0.34 %
# It 1,370: Loss = 1.3760e-02, Max. rel. error = 0.35 %
# It 1,380: Loss = 1.3733e-02, Max. rel. error = 0.36 %
# It 1,390: Loss = 1.3706e-02, Max. rel. error = 0.37 %
# It 1,400: Loss = 1.3678e-02, Max. rel. error = 0.38 %
# It 1,410: Loss = 1.3650e-02, Max. rel. error = 0.39 %
# It 1,420: Loss = 1.3620e-02, Max. rel. error = 0.41 %
# It 1,430: Loss = 1.3590e-02, Max. rel. error = 0.42 %
# It 1,440: Loss = 1.3558e-02, Max. rel. error = 0.43 %
# It 1,450: Loss = 1.3526e-02, Max. rel. error = 0.45 %
# It 1,460: Loss = 1.3493e-02, Max. rel. error = 0.46 %
# It 1,470: Loss = 1.3458e-02, Max. rel. error = 0.48 %
# It 1,480: Loss = 1.3423e-02, Max. rel. error = 0.49 %
# It 1,490: Loss = 1.3386e-02, Max. rel. error = 0.51 %
# It 1,500: Loss = 1.3348e-02, Max. rel. error = 0.53 %
# It 1,510: Loss = 1.3309e-02, Max. rel. error = 0.55 %
# It 1,520: Loss = 1.3269e-02, Max. rel. error = 0.57 %
# It 1,530: Loss = 1.3227e-02, Max. rel. error = 0.59 %
# It 1,540: Loss = 1.3184e-02, Max. rel. error = 0.61 %
# It 1,550: Loss = 1.3140e-02, Max. rel. error = 0.63 %
# It 1,560: Loss = 1.3094e-02, Max. rel. error = 0.66 %
# It 1,570: Loss = 1.3046e-02, Max. rel. error = 0.68 %
# It 1,580: Loss = 1.2997e-02, Max. rel. error = 0.71 %
# It 1,590: Loss = 1.2946e-02, Max. rel. error = 0.73 %
# It 1,600: Loss = 1.2893e-02, Max. rel. error = 0.76 %
# It 1,610: Loss = 1.2838e-02, Max. rel. error = 0.79 %
# It 1,620: Loss = 1.2782e-02, Max. rel. error = 0.83 %
# It 1,630: Loss = 1.2723e-02, Max. rel. error = 0.86 %
# It 1,640: Loss = 1.2663e-02, Max. rel. error = 0.89 %
# It 1,650: Loss = 1.2600e-02, Max. rel. error = 0.93 %
# It 1,660: Loss = 1.2535e-02, Max. rel. error = 0.97 %
# It 1,670: Loss = 1.2467e-02, Max. rel. error = 1.01 %
# It 1,680: Loss = 1.2397e-02, Max. rel. error = 1.05 %
# It 1,690: Loss = 1.2325e-02, Max. rel. error = 1.09 %
# It 1,700: Loss = 1.2250e-02, Max. rel. error = 1.14 %
# It 1,710: Loss = 1.2172e-02, Max. rel. error = 1.19 %
# It 1,720: Loss = 1.2091e-02, Max. rel. error = 1.25 %
# It 1,730: Loss = 1.2007e-02, Max. rel. error = 1.3 %
# It 1,740: Loss = 1.1920e-02, Max. rel. error = 1.35 %
# It 1,750: Loss = 1.1830e-02, Max. rel. error = 1.41 %
# It 1,760: Loss = 1.1737e-02, Max. rel. error = 1.48 %
# It 1,770: Loss = 1.1640e-02, Max. rel. error = 1.55 %
# It 1,780: Loss = 1.1540e-02, Max. rel. error = 1.62 %
# It 1,790: Loss = 1.1436e-02, Max. rel. error = 1.69 %
# It 1,800: Loss = 1.1329e-02, Max. rel. error = 1.77 %
# It 1,810: Loss = 1.1218e-02, Max. rel. error = 1.85 %
# It 1,820: Loss = 1.1103e-02, Max. rel. error = 1.93 %
# It 1,830: Loss = 1.0984e-02, Max. rel. error = 2.02 %
# It 1,840: Loss = 1.0861e-02, Max. rel. error = 2.11 %
# It 1,850: Loss = 1.0733e-02, Max. rel. error = 2.21 %
# It 1,860: Loss = 1.0602e-02, Max. rel. error = 2.31 %
# It 1,870: Loss = 1.0466e-02, Max. rel. error = 2.42 %
# It 1,880: Loss = 1.0326e-02, Max. rel. error = 2.53 %
# It 1,890: Loss = 1.0181e-02, Max. rel. error = 2.65 %
# It 1,900: Loss = 1.0032e-02, Max. rel. error = 2.77 %
# It 1,910: Loss = 9.8795e-03, Max. rel. error = 2.89 %
# It 1,920: Loss = 9.7219e-03, Max. rel. error = 3.03 %
# It 1,930: Loss = 9.5595e-03, Max. rel. error = 3.17 %
# It 1,940: Loss = 9.3933e-03, Max. rel. error = 3.31 %
# It 1,950: Loss = 9.2229e-03, Max. rel. error = 3.46 %
# It 1,960: Loss = 9.0478e-03, Max. rel. error = 3.62 %
# It 1,970: Loss = 8.8685e-03, Max. rel. error = 3.78 %
# It 1,980: Loss = 8.6857e-03, Max. rel. error = 3.95 %
# It 1,990: Loss = 8.4989e-03, Max. rel. error = 4.12 %
# It 2,000: Loss = 8.3078e-03, Max. rel. error = 4.31 %
# It 2,010: Loss = 8.1137e-03, Max. rel. error = 4.5 %
# It 2,020: Loss = 7.9166e-03, Max. rel. error = 4.68 %
# It 2,030: Loss = 7.7159e-03, Max. rel. error = 4.88 %
# It 2,040: Loss = 7.5121e-03, Max. rel. error = 5.1 %
# It 2,050: Loss = 7.3067e-03, Max. rel. error = 5.3 %
# It 2,060: Loss = 7.0988e-03, Max. rel. error = 5.51 %
# It 2,070: Loss = 6.8882e-03, Max. rel. error = 5.75 %
# It 2,080: Loss = 6.6768e-03, Max. rel. error = 5.98 %
# It 2,090: Loss = 6.4644e-03, Max. rel. error = 6.21 %
# It 2,100: Loss = 6.2506e-03, Max. rel. error = 6.45 %
# It 2,110: Loss = 6.0360e-03, Max. rel. error = 6.72 %
# It 2,120: Loss = 5.8223e-03, Max. rel. error = 6.96 %
# It 2,130: Loss = 5.6086e-03, Max. rel. error = 7.21 %
# It 2,140: Loss = 5.3949e-03, Max. rel. error = 7.5 %
# It 2,150: Loss = 5.1826e-03, Max. rel. error = 7.78 %
# It 2,160: Loss = 4.9724e-03, Max. rel. error = 8.04 %
# It 2,170: Loss = 4.7636e-03, Max. rel. error = 8.32 %
# It 2,180: Loss = 4.5565e-03, Max. rel. error = 8.64 %
# It 2,190: Loss = 4.3528e-03, Max. rel. error = 8.93 %
# It 2,200: Loss = 4.1522e-03, Max. rel. error = 9.21 %
# It 2,210: Loss = 3.9544e-03, Max. rel. error = 9.53 %
# It 2,220: Loss = 3.7597e-03, Max. rel. error = 9.88 %
# It 2,230: Loss = 3.5699e-03, Max. rel. error = 10.19 %
# It 2,240: Loss = 3.3844e-03, Max. rel. error = 10.49 %
# It 2,250: Loss = 3.2032e-03, Max. rel. error = 10.83 %
# It 2,260: Loss = 3.0265e-03, Max. rel. error = 11.19 %
# It 2,270: Loss = 2.8554e-03, Max. rel. error = 11.52 %
# It 2,280: Loss = 2.6902e-03, Max. rel. error = 11.82 %
# It 2,290: Loss = 2.5303e-03, Max. rel. error = 12.15 %
# It 2,300: Loss = 2.3760e-03, Max. rel. error = 12.51 %
# It 2,310: Loss = 2.2276e-03, Max. rel. error = 12.85 %
# It 2,320: Loss = 2.0860e-03, Max. rel. error = 13.15 %
# It 2,330: Loss = 1.9507e-03, Max. rel. error = 13.42 %
# It 2,340: Loss = 1.8215e-03, Max. rel. error = 13.74 %
# It 2,350: Loss = 1.6985e-03, Max. rel. error = 14.04 %
# It 2,360: Loss = 1.5820e-03, Max. rel. error = 14.32 %
# It 2,370: Loss = 1.4723e-03, Max. rel. error = 14.53 %
# It 2,380: Loss = 1.3689e-03, Max. rel. error = 14.73 %
# It 2,390: Loss = 1.2716e-03, Max. rel. error = 14.93 %
# It 2,400: Loss = 1.1804e-03, Max. rel. error = 15.11 %
# It 2,410: Loss = 1.0952e-03, Max. rel. error = 15.24 %
# It 2,420: Loss = 1.0160e-03, Max. rel. error = 15.31 %
# It 2,430: Loss = 9.4248e-04, Max. rel. error = 15.33 %
# It 2,440: Loss = 8.7437e-04, Max. rel. error = 15.33 %
# It 2,450: Loss = 8.1151e-04, Max. rel. error = 15.28 %
# It 2,460: Loss = 7.5369e-04, Max. rel. error = 15.16 %
# It 2,470: Loss = 7.0066e-04, Max. rel. error = 14.98 %
# It 2,480: Loss = 6.5204e-04, Max. rel. error = 14.77 %
# It 2,490: Loss = 6.0767e-04, Max. rel. error = 14.5 %
# It 2,500: Loss = 5.6731e-04, Max. rel. error = 14.16 %
# It 2,510: Loss = 5.3073e-04, Max. rel. error = 13.75 %
# It 2,520: Loss = 4.9769e-04, Max. rel. error = 13.27 %
# It 2,530: Loss = 4.6791e-04, Max. rel. error = 12.74 %
# It 2,540: Loss = 4.4072e-04, Max. rel. error = 12.27 %
# It 2,550: Loss = 4.1628e-04, Max. rel. error = 11.78 %
# It 2,560: Loss = 3.9438e-04, Max. rel. error = 11.16 %
# It 2,570: Loss = 3.7482e-04, Max. rel. error = 10.51 %
# It 2,580: Loss = 3.5739e-04, Max. rel. error = 9.84 %
# It 2,590: Loss = 3.4187e-04, Max. rel. error = 9.17 %
# It 2,600: Loss = 3.2803e-04, Max. rel. error = 8.5 %
# It 2,610: Loss = 3.1516e-04, Max. rel. error = 8.06 %
# It 2,620: Loss = 3.0367e-04, Max. rel. error = 7.64 %
# It 2,630: Loss = 2.9345e-04, Max. rel. error = 7.04 %
# It 2,640: Loss = 2.8435e-04, Max. rel. error = 6.47 %
# It 2,650: Loss = 2.7624e-04, Max. rel. error = 5.94 %
# It 2,660: Loss = 2.6899e-04, Max. rel. error = 5.44 %
# It 2,670: Loss = 2.6249e-04, Max. rel. error = 4.99 %
# It 2,680: Loss = 2.5663e-04, Max. rel. error = 4.59 %
# It 2,690: Loss = 2.5099e-04, Max. rel. error = 4.34 %
# It 2,700: Loss = 2.4556e-04, Max. rel. error = 4.29 %
# It 2,710: Loss = 2.4062e-04, Max. rel. error = 4.11 %
# It 2,720: Loss = 2.3610e-04, Max. rel. error = 3.82 %
# It 2,730: Loss = 2.3194e-04, Max. rel. error = 3.57 %
# It 2,740: Loss = 2.2806e-04, Max. rel. error = 3.35 %
# It 2,750: Loss = 2.2444e-04, Max. rel. error = 3.18 %
# It 2,760: Loss = 2.2102e-04, Max. rel. error = 3.03 %
# It 2,770: Loss = 2.1777e-04, Max. rel. error = 2.91 %
# It 2,780: Loss = 2.1466e-04, Max. rel. error = 2.82 %
# It 2,790: Loss = 2.1167e-04, Max. rel. error = 2.74 %
# It 2,800: Loss = 2.0877e-04, Max. rel. error = 2.68 %
# It 2,810: Loss = 2.0571e-04, Max. rel. error = 2.73 %
# It 2,820: Loss = 2.0249e-04, Max. rel. error = 2.94 %
# It 2,830: Loss = 1.9940e-04, Max. rel. error = 3.01 %
# It 2,840: Loss = 1.9644e-04, Max. rel. error = 2.93 %
# It 2,850: Loss = 1.9356e-04, Max. rel. error = 2.87 %
# It 2,860: Loss = 1.9076e-04, Max. rel. error = 2.83 %
# It 2,870: Loss = 1.8801e-04, Max. rel. error = 2.8 %
# It 2,880: Loss = 1.8532e-04, Max. rel. error = 2.79 %
# It 2,890: Loss = 1.8267e-04, Max. rel. error = 2.78 %
# It 2,900: Loss = 1.8005e-04, Max. rel. error = 2.78 %
# It 2,910: Loss = 1.7747e-04, Max. rel. error = 2.78 %
# It 2,920: Loss = 1.7491e-04, Max. rel. error = 2.79 %
# It 2,930: Loss = 1.7238e-04, Max. rel. error = 2.8 %
# It 2,940: Loss = 1.6988e-04, Max. rel. error = 2.81 %
# It 2,950: Loss = 1.6740e-04, Max. rel. error = 2.83 %
# It 2,960: Loss = 1.6494e-04, Max. rel. error = 2.84 %
# It 2,970: Loss = 1.6250e-04, Max. rel. error = 2.86 %
# It 2,980: Loss = 1.6009e-04, Max. rel. error = 2.87 %
# It 2,990: Loss = 1.5764e-04, Max. rel. error = 2.89 %
# It 3,000: Loss = 1.5490e-04, Max. rel. error = 3.17 %
#
# Runtime: 3.033 minutes

# %%
solver.plot_loss_history()
# Out:
# <Axes: xlabel='$n_{epoch}$', ylabel='$loss$'>

# %%
model.eval()
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
# 颜色字典
colors = {
    'red': 'tab:red',
    'orange': 'tab:orange',
    'yellow': '#f9c74f',
    'green': 'tab:green',
    'cyan': 'tab:cyan',
    'blue': 'tab:blue',
    'purple': 'tab:purple',
    'brown': 'tab:brown',
    'pink': 'tab:pink',
    'black': '#000000'  # 添加黑色
}
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
# 计算等间隔的索引
num_points = len(data_valid)
step = max(1, num_points//50000)  # 确保步长至少为1
sampled_indices = range(1, num_points, step)
    
# 按等间隔取点
sampled_test_data = data_valid.iloc[sampled_indices]    
y_MF = model(X_data_valid) 
# 反归一化 y_MF
y_MF=y_MF.cpu().detach().numpy()
# 提取后三列的归一化参数
y_min = scaler.data_min_[-3:]  # 后三列的最小值
y_max = scaler.data_max_[-3:]  # 后三列的最大值
# 手动反归一化
y_MF_denorm = y_MF * (y_max - y_min) + y_min
    # 绘制数据
ax.plot(data_valid['Time'].values[time_steps-1:], y_MF_denorm[:,2], color=colors['blue'],label='GRU')

ax.scatter(data_valid['Time'].values, data_valid['σ12'].values, color=colors['black'], marker='o', 
            label='Test',s=12)
    
    
    
# ax.axvspan(1, 100, color='gray', alpha=0.2) 突出标记
# ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_ylabel('$Stress$$\mathrm{[Pa]}$')
ax.set_xlabel('$Time$[s]')
# ax.grid()
# 调整图例的大小和位置
legend = ax.legend(fontsize=8, loc='lower right', bbox_to_anchor=(0.26, 0.86))
#ax.invert_xaxis()
plt.show()

# %%
torch.save(model, 'model/giesukus_gru_linear.pth')

# %%
# 假设你已经使用了 GPU
x = torch.randn(10, 10).cuda()

# 清空未使用的显存缓存
torch.cuda.empty_cache()

# %% [markdown]
# ## sigma12

# %%
model_dnn_12=torch.load('model/giesukus_dnn_linear.pth')
model_gru_12=torch.load('model/giesukus_gru_linear.pth')
model_dnn_12.eval()
model_gru_12.eval()
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
# 颜色字典
colors = {
    'red': 'tab:red',
    'orange': 'tab:orange',
    'yellow': '#f9c74f',
    'green': 'tab:green',
    'cyan': 'tab:cyan',
    'blue': 'tab:blue',
    'purple': 'tab:purple',
    'brown': 'tab:brown',
    'pink': 'tab:pink',
    'black': '#000000'  # 添加黑色
}
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
# 计算等间隔的索引
num_points = len(data_valid)
step = max(1, num_points//500)  # 确保步长至少为1
sampled_indices = range(1, num_points, step)
    
# 按等间隔取点
sampled_test_data = data_valid.iloc[sampled_indices]    
y_dnn = model_dnn_12(X_data_valid) 
y_gru = model_gru_12(X_data_valid) 
# 反归一化 y_MF
y_dnn=y_dnn.cpu().detach().numpy()
y_gru=y_gru.cpu().detach().numpy()
# 提取后三列的归一化参数
y_min = scaler.data_min_[-3:]  # 后三列的最小值
y_max = scaler.data_max_[-3:]  # 后三列的最大值
# 手动反归一化
y_dnn_denorm = y_dnn * (y_max - y_min) + y_min
y_gru_denorm = y_gru * (y_max - y_min) + y_min
ax.plot(data_valid['Time'].values[time_steps-1:], y_dnn_denorm[:,2], color=colors['blue'],label='DNN')
ax.plot(data_valid['Time'].values[time_steps-1:], y_gru_denorm[:,2], color=colors['green'],label='GRU')

ax.scatter(sampled_test_data['Time'].values, sampled_test_data['σ12'].values, color=colors['black'], marker='o', 
            label='Test',s=12,facecolors='none')
    
    
    
# ax.axvspan(1, 100, color='gray', alpha=0.2) 突出标记
# ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_ylabel('$\sigma_{12}$$\mathrm{[Pa]}$')
ax.set_xlabel('$Time$[s]')
# 设置 x 轴和 y 轴的范围
#ax.set_xlim(0, 25)  # x 轴范围从 0 到 6
#ax.set_ylim(-0.8, 1)  # y 轴范围从 0 到 30
# 调整图例的大小和位置
legend = ax.legend(fontsize=10, loc='lower right', bbox_to_anchor=(0.96, 0.29))
#ax.invert_xaxis()
plt.show()
# Out:
# /tmp/ipykernel_19050/3151600353.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_dnn_12=torch.load('model/giesukus_dnn_linear.pth')
# /tmp/ipykernel_19050/3151600353.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_gru_12=torch.load('model/giesukus_gru_linear.pth')

# %% [markdown]
# ### 计算指标

# %%
R2 = []
MAE = []
MSE = []
MAPE=[]
def calculate_mape(y_true, y_pred):
    # 过滤掉 y_true 为 0 的样本
    valid_indices = y_true != 0
    y_true_valid = y_true[valid_indices]
    y_pred_valid = y_pred[valid_indices]
    absolute_percentage_error = np.abs((y_true_valid - y_pred_valid) / y_true_valid)
    # 计算平均值并乘以 100 得到百分比
    mape = np.mean(absolute_percentage_error) 
    return mape
# 计算并存储指标/DNN
R2.append(r2_score(y_dnn_denorm[:,2], data_valid['σ12'].values[time_steps-1:]))
MAE.append(mean_absolute_error(y_dnn_denorm[:,2],data_valid['σ12'].values[time_steps-1:]))
MSE.append(mean_squared_error(y_dnn_denorm[:,2], data_valid['σ12'].values[time_steps-1:]))
MAPE.append(calculate_mape(data_valid['σ12'].values[time_steps-1:], y_dnn_denorm[:,2]))

# 计算并存储指标/GRU
R2.append(r2_score(y_gru_denorm[:,2], data_valid['σ12'].values[time_steps-1:]))
MAE.append(mean_absolute_error(y_gru_denorm[:,2], data_valid['σ12'].values[time_steps-1:]))
MSE.append(mean_squared_error(y_gru_denorm[:,2], data_valid['σ12'].values[time_steps-1:]))
MAPE.append(calculate_mape(data_valid['σ12'].values[time_steps-1:], y_gru_denorm[:,2]))
# 格式化数值为四位小数
R2 = [f"{x:.4f}" for x in R2]
MAE = [f"{x:.4f}" for x in MAE]
MSE = [f"{x:.4f}" for x in MSE]
MAPE = [f"{x:.4f}" for x in MAPE]

# 绘制表格
data = {
    'Model': ['DNN', 'GRU'],
    'R2': R2,
    'MAE': MAE,
    'MSE': MSE,
    'MAPE': MAPE
}

df = pd.DataFrame(data)

# 使用 matplotlib 绘制三线表
fig, ax = plt.subplots(figsize=(8, 4))
ax.axis('off')  # 关闭坐标轴

# 绘制表格
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# 设置表格样式
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)  # 调整表格大小
# 保存表格为图片
# plt.savefig('model_performance_table.png', bbox_inches='tight', dpi=300)

# 显示表格
plt.show()

# %% [markdown]
# 绘制第一法向应力差

# %%
time_steps=40
model_dnn_11=torch.load('model/giesukus_dnn_sigma11.pth')
model_gru_11=torch.load('model/giesukus_gru_sigma11.pth')
model_dnn_11.eval()
model_gru_11.eval()
model_dnn_22=torch.load('model/giesukus_dnn_sigma22.pth')
model_gru_22=torch.load('model/giesukus_gru_sigma22.pth')
model_dnn_22.eval()
model_gru_22.eval()
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
# 颜色字典
colors = {
    'red': 'tab:red',
    'orange': 'tab:orange',
    'yellow': '#f9c74f',
    'green': 'tab:green',
    'cyan': 'tab:cyan',
    'blue': 'tab:blue',
    'purple': 'tab:purple',
    'brown': 'tab:brown',
    'pink': 'tab:pink',
    'black': '#000000'  # 添加黑色
}
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
# 计算等间隔的索引
num_points = len(data_valid)
step = max(1, num_points//500)  # 确保步长至少为1
sampled_indices = range(1, num_points, step)
    
# 按等间隔取点
sampled_test_data = data_valid.iloc[sampled_indices]    
y_dnn_11 = model_dnn_11(X_data_valid) 
y_dnn_22 = model_dnn_22(X_data_valid) 
y_gru_11 = model_gru_11(X_data_valid) 
y_gru_22 = model_gru_22(X_data_valid) 
# 反归一化 y_MF
y_dnn_11=y_dnn_11.cpu().detach().numpy()
y_dnn_22=y_dnn_22.cpu().detach().numpy()
y_gru_11=y_gru_11.cpu().detach().numpy()
y_gru_22=y_gru_22.cpu().detach().numpy()
# 提取后三列的归一化参数
y_min = scaler.data_min_[-3:]  # 后三列的最小值
y_max = scaler.data_max_[-3:]  # 后三列的最大值
# 手动反归一化
y_dnn_11_denorm = y_dnn_11 * (y_max - y_min) + y_min
y_dnn_22_denorm = y_dnn_22 * (y_max - y_min) + y_min
y_gru_11_denorm = y_gru_11 * (y_max - y_min) + y_min
y_gru_22_denorm = y_gru_22 * (y_max - y_min) + y_min
    # 绘制数据
ax.plot(data_valid['Time'].values[time_steps-1:], y_dnn_11_denorm[:,0]-y_dnn_22_denorm[:,1], color=colors['blue'],label='DNN')
ax.plot(data_valid['Time'].values[time_steps-1:], y_gru_11_denorm[:,0]-y_gru_22_denorm[:,1], color=colors['green'],label='GRU')

ax.scatter(sampled_test_data['Time'].values[time_steps-1:],
            sampled_test_data['σ11'].values[time_steps-1:]-sampled_test_data['σ22'].values[time_steps-1:],
            color=colors['black'], marker='o', 
            label='Test',s=12,facecolors='none')
    
    
    
# ax.axvspan(1, 100, color='gray', alpha=0.2) 突出标记
# ax.set_xscale('log')
#ax.set_yscale('log')
ax.set_ylabel('$N_{1}$$\mathrm{[Pa]}$')
ax.set_xlabel('$Time$[s]')
# 设置 x 轴和 y 轴的范围
ax.set_xlim(0, 25)  # x 轴范围从 0 到 25
ax.set_ylim(0, 0.8)  # y 轴范围从 0 到 1
# 调整图例的大小和位置
legend = ax.legend(fontsize=10, loc='lower right', bbox_to_anchor=(0.26, 0.8))
#ax.invert_xaxis()
plt.show()
# Out:
# /tmp/ipykernel_15659/2713941411.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_dnn_11=torch.load('model/giesukus_dnn_sigma11.pth')
# /tmp/ipykernel_15659/2713941411.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_gru_11=torch.load('model/giesukus_gru_sigma11.pth')
# /tmp/ipykernel_15659/2713941411.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_dnn_22=torch.load('model/giesukus_dnn_sigma22.pth')
# /tmp/ipykernel_15659/2713941411.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_gru_22=torch.load('model/giesukus_gru_sigma22.pth')

# %% [markdown]
# ### 计算指标

# %%
R2 = []
MAE = []
MSE = []
MAPE=[]
def calculate_mape(y_true, y_pred):
    # 计算每个样本的绝对百分比误差
    absolute_percentage_error = np.abs((y_true - y_pred) / y_true)
    # 计算平均值并乘以 100 得到百分比
    mape = np.mean(absolute_percentage_error) 
    return mape
# 计算并存储指标/DNN
N1_dnn=y_dnn_11_denorm[:,0]-y_dnn_22_denorm[:,1]
N1_gru=y_gru_11_denorm[:,0]-y_gru_22_denorm[:,1]
N1_test=data_valid['σ11'].values[time_steps-1:]-data_valid['σ22'].values[time_steps-1:]
R2.append(r2_score(N1_dnn, N1_test))
MAE.append(mean_absolute_error(N1_dnn,N1_test))
MSE.append(mean_squared_error(N1_dnn,N1_test))
MAPE.append(calculate_mape(N1_dnn,N1_test))

# 计算并存储指标/GRU
R2.append(r2_score(N1_gru,N1_test))
MAE.append(mean_absolute_error(N1_gru,N1_test))
MSE.append(mean_squared_error(N1_gru,N1_test))
MAPE.append(calculate_mape(N1_gru,N1_test))
# 格式化数值为四位小数
R2 = [f"{x:.4f}" for x in R2]
MAE = [f"{x:.4f}" for x in MAE]
MSE = [f"{x:.4f}" for x in MSE]
MAPE = [f"{x:.4f}" for x in MAPE]

# 绘制表格
data = {
    'Model': ['DNN', 'GRU'],
    'R2': R2,
    'MAE': MAE,
    'MSE': MSE,
    'MAPE': MAPE
}

df = pd.DataFrame(data)

# 使用 matplotlib 绘制三线表
fig, ax = plt.subplots(figsize=(8, 4))
ax.axis('off')  # 关闭坐标轴

# 绘制表格
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# 设置表格样式
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)  # 调整表格大小
# 保存表格为图片
# plt.savefig('model_performance_table.png', bbox_inches='tight', dpi=300)

# 显示表格
plt.show()
